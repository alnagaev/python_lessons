# %% [markdown]
# ## Знакомство с pandas
#
# pandas — программная библиотека на языке Python для обработки и анализа данных. Работа pandas с данными строится поверх библиотеки NumPy, являющейся инструментом более низкого уровня. Предоставляет специальные структуры данных и операции для манипулирования числовыми таблицами и временны́ми рядами. Название библиотеки происходит от эконометрического термина «панельные данные» (англ. panel data), используемого для описания многомерных структурированных наборов информации.

# %% [markdown]
# https://khashtamov.com/ru/pandas-introduction/
#
# https://habr.com/ru/company/ruvds/blog/442516/
#
# https://proglib.io/p/pandas-tricks/
#
# https://pandas.pydata.org/pandas-docs/stable/getting_started/10min.html

# %% [markdown]
# Основные возможности библиотеки:
#
#     - Объект DataFrame для манипулирования индексированными массивами двумерных данных
#     - Инструменты для обмена данными между структурами в памяти и файлами различных форматов
#     - Встроенные средства совмещения данных и способы обработки отсутствующей информации
#     - Переформатирование наборов данных, в том числе создание сводных таблиц
#     - Срез данных по значениям индекса, расширенные возможности индексирования, выборка из больших наборов данных
#     - Вставка и удаление столбцов данных
#     - Возможности группировки позволяют выполнять трёхэтапные операции типа «разделение, изменение, объединение» (англ. split-apply-combine).
#     - Слияние и объединение наборов данных
#     - Иерархическое индексирование позволяет работать с данными высокой размерности в структурах меньшей размерности
#     - Работа с временными рядами: формирование временных периодов и изменение интервалов и так далее
#
# Библиотека оптимизирована для высокой производительности, наиболее важные части кода написаны на Cython и Си.

# %%
#импортируем библиотеку pandas
import pandas as pd

# %%
d = {'col1': [1, 2], 'col2': [3, 4]}
df = pd.DataFrame(data=d)
df
# Out:
#    col1  col2
# 0     1     3
# 1     2     4

# %% [markdown]
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html

# %%
#Создание таблицы с помощью открытия csv файла

df = pd.read_csv('https://raw.githubusercontent.com/alnagaev/landing/master/train.csv') 
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#Описываем датасет с технической точки зрения: длина, типы данных и пропущенные значения
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
# PassengerId    891 non-null int64
# Survived       891 non-null int64
# Pclass         891 non-null int64
# Name           891 non-null object
# Sex            891 non-null object
# Age            714 non-null float64
# SibSp          891 non-null int64
# Parch          891 non-null int64
# Ticket         891 non-null object
# Fare           891 non-null float64
# Cabin          204 non-null object
# Embarked       889 non-null object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#Описываем датасет с семантической точки зрения: количество значений, среднее, стандартное отклонение и т.д

# df.describe()
df.describe(include=['O'])
# df.describe(include='all')
# Out:
#                             Name   Sex    Ticket Cabin Embarked
# count                        891   891       891   204      889
# unique                       891     2       681   147        3
# top     Sage, Mr. George John Jr  male  CA. 2343    G6        S
# freq                           1   577         7     4      644

# %%
df['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888     NaN
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
#normalize=False
round(df['Pclass'].value_counts(normalize=True), 2)*100
# Out:
# 3    55.0
# 1    24.0
# 2    21.0
# Name: Pclass, dtype: float64

# %%
df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
import matplotlib 
df['Age'].hist()

# %%
list(df)
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
df['New'] = 5
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  New
# 0        0         A/5 21171   7.2500   NaN        S    5
# 1        0          PC 17599  71.2833   C85        C    5
# 2        0  STON/O2. 3101282   7.9250   NaN        S    5
# 3        0            113803  53.1000  C123        S    5
# 4        0            373450   8.0500   NaN        S    5
# ..     ...               ...      ...   ...      ...  ...
# 886      0            211536  13.0000   NaN        S    5
# 887      0            112053  30.0000   B42        S    5
# 888      2        W./C. 6607  23.4500   NaN        S    5
# 889      0            111369  30.0000  C148        C    5
# 890      0            370376   7.7500   NaN        Q    5
#
# [891 rows x 13 columns]

# %%
cols = ['Survived', 'Pclass', 'Sex', 'Age', 'SibSp', 'Parch', 'Fare', 'Embarked']
df[cols]
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female   NaN      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
df[0:7]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
# 5            6         0       3
# 6            7         0       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
# 5                                   Moran, Mr. James    male   NaN      0
# 6                            McCarthy, Mr. Timothy J    male  54.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  New
# 0      0         A/5 21171   7.2500   NaN        S    0
# 1      0          PC 17599  71.2833   C85        C    1
# 2      0  STON/O2. 3101282   7.9250   NaN        S    2
# 3      0            113803  53.1000  C123        S    3
# 4      0            373450   8.0500   NaN        S    4
# 5      0            330877   8.4583   NaN        Q    5
# 6      0             17463  51.8625   E46        S    6

# %%
df[5:10:2]
# Out:
#    PassengerId  Survived  Pclass                                 Name     Sex  \
# 5            6         0       3                     Moran, Mr. James    male
# 7            8         0       3       Palsson, Master. Gosta Leonard    male
# 9           10         1       2  Nasser, Mrs. Nicholas (Adele Achem)  female
#
#     Age  SibSp  Parch  Ticket     Fare Cabin Embarked  New
# 5   NaN      0      0  330877   8.4583   NaN        Q    5
# 7   2.0      3      1  349909  21.0750   NaN        S    7
# 9  14.0      1      0  237736  30.0708   NaN        C    9

# %%
james = df[df.Name.str.contains('James')]
james
# Out:
#      PassengerId  Survived  Pclass  \
# 5              6         0       3
# 67            68         0       3
# 134          135         0       2
# 150          151         0       2
# 161          162         1       2
# 174          175         0       1
# 194          195         1       1
# 221          222         0       2
# 250          251         0       3
# 299          300         1       1
# 416          417         1       2
# 428          429         0       3
# 468          469         0       3
# 511          512         0       3
# 512          513         1       1
# 525          526         0       3
# 551          552         0       2
# 582          583         0       2
# 592          593         0       3
# 696          697         0       3
# 740          741         1       1
# 811          812         0       3
# 812          813         0       2
# 883          884         0       2
#
#                                                   Name     Sex   Age  SibSp  \
# 5                                     Moran, Mr. James    male   NaN      0
# 67                            Crease, Mr. Ernest James    male  19.0      0
# 134                     Sobey, Mr. Samuel James Hayden    male  25.0      0
# 150                         Bateman, Rev. Robert James    male  51.0      0
# 161  Watt, Mrs. James (Elizabeth "Bessie" Inglis Mi...  female  40.0      0
# 174                            Smith, Mr. James Clinch    male  56.0      0
# 194          Brown, Mrs. James Joseph (Margaret Tobin)  female  44.0      0
# 221                               Bracken, Mr. James H    male  27.0      0
# 250                             Reed, Mr. James George    male   NaN      0
# 299    Baxter, Mrs. James (Helene DeLaudeniere Chaput)  female  50.0      0
# 416    Drew, Mrs. James Vivian (Lulu Thorne Christian)  female  34.0      1
# 428                                   Flynn, Mr. James    male   NaN      0
# 468                                 Scanlan, Mr. James    male   NaN      0
# 511                                  Webber, Mr. James    male   NaN      0
# 512                          McGough, Mr. James Robert    male  36.0      0
# 525                                 Farrell, Mr. James    male  40.5      0
# 551                        Sharp, Mr. Percival James R    male  27.0      0
# 582                         Downton, Mr. William James    male  54.0      0
# 592                         Elsbury, Mr. William James    male  47.0      0
# 696                                   Kelly, Mr. James    male  44.0      0
# 740                        Hawksford, Mr. Walter James    male   NaN      0
# 811                                  Lester, Mr. James    male  39.0      0
# 812                          Slemen, Mr. Richard James    male  35.0      0
# 883                      Banfield, Mr. Frederick James    male  28.0      0
#
#      Parch            Ticket      Fare    Cabin Embarked  New
# 5        0            330877    8.4583      NaN        Q    5
# 67       0         S.P. 3464    8.1583      NaN        S   67
# 134      0        C.A. 29178   13.0000      NaN        S  134
# 150      0       S.O.P. 1166   12.5250      NaN        S  150
# 161      0        C.A. 33595   15.7500      NaN        S  161
# 174      0             17764   30.6958       A7        C  174
# 194      0          PC 17610   27.7208       B4        C  194
# 221      0            220367   13.0000      NaN        S  221
# 250      0            362316    7.2500      NaN        S  250
# 299      1          PC 17558  247.5208  B58 B60        C  299
# 416      1             28220   32.5000      NaN        S  416
# 428      0            364851    7.7500      NaN        Q  428
# 468      0             36209    7.7250      NaN        Q  468
# 511      0  SOTON/OQ 3101316    8.0500      NaN        S  511
# 512      0          PC 17473   26.2875      E25        S  512
# 525      0            367232    7.7500      NaN        Q  525
# 551      0            244358   26.0000      NaN        S  551
# 582      0             28403   26.0000      NaN        S  582
# 592      0          A/5 3902    7.2500      NaN        S  592
# 696      0            363592    8.0500      NaN        S  696
# 740      0             16988   30.0000      D45        S  740
# 811      0         A/4 48871   24.1500      NaN        S  811
# 812      0             28206   10.5000      NaN        S  812
# 883      0  C.A./SOTON 34068   10.5000      NaN        S  883

# %%
df[df.columns[0]]
# Out:
# 0        1
# 1        2
# 2        3
# 3        4
# 4        5
#       ...
# 886    887
# 887    888
# 888    889
# 889    890
# 890    891
# Name: PassengerId, Length: 891, dtype: int64

# %%
df['Pclass']
# Out:
# 0      3
# 1      1
# 2      3
# 3      1
# 4      3
#       ..
# 886    2
# 887    1
# 888    3
# 889    1
# 890    3
# Name: Pclass, Length: 891, dtype: int64

# %%
df.loc[5:8, ['Survived', 'Pclass']]
# Out:
#    Survived  Pclass
# 5         0       3
# 6         0       1
# 7         0       3
# 8         1       3

# %%
df.iloc[3:5]
# Out:
#    PassengerId  Survived  Pclass  \
# 3            4         1       1
# 4            5         0       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 3  Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1      0
# 4                      Allen, Mr. William Henry    male  35.0      0      0
#
#    Ticket   Fare Cabin Embarked
# 3  113803  53.10  C123        S
# 4  373450   8.05   NaN        S

# %%
df.iloc[:, 0:2]
# Out:
#      PassengerId  Survived
# 0              1         0
# 1              2         1
# 2              3         1
# 3              4         1
# 4              5         0
# ..           ...       ...
# 886          887         0
# 887          888         1
# 888          889         0
# 889          890         1
# 890          891         0
#
# [891 rows x 2 columns]

# %%
df[(df.Age > 20) & (df.Age < 40)]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 884          885         0       3
# 885          886         0       3
# 886          887         0       2
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 884                             Sutehall, Mr. Henry Jr    male  25.0      0
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked  New
# 0        0         A/5 21171   7.2500   NaN        S    0
# 1        0          PC 17599  71.2833   C85        C    1
# 2        0  STON/O2. 3101282   7.9250   NaN        S    2
# 3        0            113803  53.1000  C123        S    3
# 4        0            373450   8.0500   NaN        S    4
# ..     ...               ...      ...   ...      ...  ...
# 884      0   SOTON/OQ 392076   7.0500   NaN        S  884
# 885      5            382652  29.1250   NaN        Q  885
# 886      0            211536  13.0000   NaN        S  886
# 889      0            111369  30.0000  C148        C  889
# 890      0            370376   7.7500   NaN        Q  890
#
# [372 rows x 13 columns]

# %%
df[(df.Age > 20) & (df.Sex == 'male') & (df.Name.str.contains('James'))]
# Out:
#      PassengerId  Survived  Pclass                            Name   Sex  \
# 134          135         0       2  Sobey, Mr. Samuel James Hayden  male
# 150          151         0       2      Bateman, Rev. Robert James  male
# 174          175         0       1         Smith, Mr. James Clinch  male
# 221          222         0       2            Bracken, Mr. James H  male
# 512          513         1       1       McGough, Mr. James Robert  male
# 525          526         0       3              Farrell, Mr. James  male
# 551          552         0       2     Sharp, Mr. Percival James R  male
# 582          583         0       2      Downton, Mr. William James  male
# 592          593         0       3      Elsbury, Mr. William James  male
# 696          697         0       3                Kelly, Mr. James  male
# 811          812         0       3               Lester, Mr. James  male
# 812          813         0       2       Slemen, Mr. Richard James  male
# 883          884         0       2   Banfield, Mr. Frederick James  male
#
#       Age  SibSp  Parch            Ticket     Fare Cabin Embarked  New
# 134  25.0      0      0        C.A. 29178  13.0000   NaN        S  134
# 150  51.0      0      0       S.O.P. 1166  12.5250   NaN        S  150
# 174  56.0      0      0             17764  30.6958    A7        C  174
# 221  27.0      0      0            220367  13.0000   NaN        S  221
# 512  36.0      0      0          PC 17473  26.2875   E25        S  512
# 525  40.5      0      0            367232   7.7500   NaN        Q  525
# 551  27.0      0      0            244358  26.0000   NaN        S  551
# 582  54.0      0      0             28403  26.0000   NaN        S  582
# 592  47.0      0      0          A/5 3902   7.2500   NaN        S  592
# 696  44.0      0      0            363592   8.0500   NaN        S  696
# 811  39.0      0      0         A/4 48871  24.1500   NaN        S  811
# 812  35.0      0      0             28206  10.5000   NaN        S  812
# 883  28.0      0      0  C.A./SOTON 34068  10.5000   NaN        S  883

# %%
import numpy as np
rand = np.random.rand(891)

# %%
df['rand'] = rand
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked      rand
# 0      0         A/5 21171   7.2500   NaN        S  0.654468
# 1      0          PC 17599  71.2833   C85        C  0.030564
# 2      0  STON/O2. 3101282   7.9250   NaN        S  0.570746
# 3      0            113803  53.1000  C123        S  0.431105
# 4      0            373450   8.0500   NaN        S  0.367612

# %%
df['Alone'] = df.apply(lambda x: 'not_alone' if x['SibSp']  or x['Parch'] > 0 else 'alone', axis = 1)
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked      rand      Alone
# 0      0         A/5 21171   7.2500   NaN        S  0.654468  not_alone
# 1      0          PC 17599  71.2833   C85        C  0.030564  not_alone
# 2      0  STON/O2. 3101282   7.9250   NaN        S  0.570746      alone
# 3      0            113803  53.1000  C123        S  0.431105  not_alone
# 4      0            373450   8.0500   NaN        S  0.367612      alone

# %% [markdown]
# ### Пропущенные значения

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# New              0
# dtype: int64

# %%
#inplace = False, если хотим заменить датафрейм то меняем на True
df.dropna(how='any')
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch    Ticket     Fare        Cabin Embarked      rand      Alone
# 1        0  PC 17599  71.2833          C85        C  0.030564  not_alone
# 3        0    113803  53.1000         C123        S  0.431105  not_alone
# 6        0     17463  51.8625          E46        S  0.724114      alone
# 10       1   PP 9549  16.7000           G6        S  0.286250  not_alone
# 11       0    113783  26.5500         C103        S  0.652761      alone
# ..     ...       ...      ...          ...      ...       ...        ...
# 871      1     11751  52.5542          D35        S  0.265673  not_alone
# 872      0       695   5.0000  B51 B53 B55        S  0.406155      alone
# 879      1     11767  83.1583          C50        C  0.177689  not_alone
# 887      0    112053  30.0000          B42        S  0.869667      alone
# 889      0    111369  30.0000         C148        C  0.534593      alone
#
# [183 rows x 14 columns]

# %%
df.groupby('Survived').agg('mean')
# Out:
#           PassengerId    Pclass        Age     SibSp     Parch       Fare  \
# Survived
# 0          447.016393  2.531876  30.626179  0.553734  0.329690  22.117887
# 1          444.368421  1.950292  28.343690  0.473684  0.464912  48.395408
#
#               rand
# Survived
# 0         0.507869
# 1         0.512971

# %% [markdown]
# Принцип действия **groupby**
# ![](https://i.stack.imgur.com/sgCn1.jpg)
#
# - Разделение данных по группап по определенному критерию
#
# - Применение к каждой группе определенной функции
#
# - Сложение результатов в единую структуру

# %%
df.groupby('Pclass').agg('median')
# Out:
#         PassengerId  Survived   Age  SibSp  Parch     Fare      rand
# Pclass
# 1             472.0       1.0  37.0    0.0    0.0  60.2875  0.454753
# 2             435.5       0.0  29.0    0.0    0.0  14.2500  0.501414
# 3             432.0       0.0  24.0    0.0    0.0   8.0500  0.543767

# %%
df.groupby(['Age', 'Fare']).sum()
# Out:
#                PassengerId  Survived  Pclass  SibSp  Parch      rand
# Age   Fare
# 0.42  8.5167           804         1       3      0      1  0.545396
# 0.67  14.5000          756         1       2      1      1  0.609618
# 0.75  19.2583         1115         2       6      4      2  1.232874
# 0.83  18.7500          832         1       2      1      1  0.179134
#       29.0000           79         1       2      0      2  0.405361
# ...                    ...       ...     ...    ...    ...       ...
# 70.50 7.7500           117         0       3      0      0  0.635964
# 71.00 34.6542           97         0       1      0      0  0.262203
#       49.5042          494         0       1      0      0  0.191312
# 74.00 7.7750           852         0       3      0      0  0.839485
# 80.00 30.0000          631         1       1      0      0  0.168352
#
# [638 rows x 6 columns]

# %% [markdown]
# #### Заменить пропущенные значения в столбце Age медианным значением возраста

# %%
df.fillna(df['Age'].median())['Age']
# Out:
# 0      22.0
# 1      38.0
# 2      26.0
# 3      35.0
# 4      35.0
#        ...
# 886    27.0
# 887    19.0
# 888    28.0
# 889    26.0
# 890    32.0
# Name: Age, Length: 891, dtype: float64

# %%
df = pd.DataFrame([[4, 9]] * 3, columns=['A', 'B'])

df
# Out:
#    A  B
# 0  4  9
# 1  4  9
# 2  4  9

# %%
df['C'] = df['A'].apply(lambda x: x*2)
df
# Out:
#    A  B  C
# 0  4  9  8
# 1  4  9  8
# 2  4  9  8

# %%
df.mean()
# Out:
# PassengerId    446.000000
# Survived         0.383838
# Pclass           2.308642
# Age             29.066409
# SibSp            0.523008
# Parch            0.381594
# Fare            32.204208
# rand             0.509828
# dtype: float64

# %%
### Работа с текстовыми данными

s = pd.Series(['A', 'B', 'C', 'Aaba', 'Baca', np.nan, 'CABA', 'dog', 'cat'])

s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
df = pd.DataFrame({"A": ["small", "large", "large", "small",

                         "small", "large", "small", "small",

                         "large"],

                   "B": [1, 2, 2, 3, 3, 4, 5, 6, 7],

                   "C": [2, 4, 5, 5, 6, 6, 8, 9, 9]})
df
# Out:
#        A  B  C
# 0  small  1  2
# 1  large  2  4
# 2  large  2  5
# 3  small  3  5
# 4  small  3  6
# 5  large  4  6
# 6  small  5  8
# 7  small  6  9
# 8  large  7  9

# %%
table = pd.pivot_table(df, values='B', index=['A'],

                    columns=['C'], aggfunc=np.sum)
table
# Out:
# C        2    4    5    6    8    9
# A
# large  NaN  2.0  2.0  4.0  NaN  7.0
# small  1.0  NaN  3.0  3.0  5.0  6.0

# %% [markdown]
# ### Время и даты в pandas

# %%
df = pd.read_csv('https://raw.githubusercontent.com/alnagaev/reni_land/master/test.csv')
df.head()
# Out:
#    id Дата рождения                           Вакансия Технология  \
# 0   1    18.04.1994    Инженер-программист 2 категории         JS
# 1   2    27.03.1993  Разработчик информационных систем       .NET
# 2   3    24.11.1983                     Java Developer       Java
# 3   4    09.06.1989                      Архитектор ПО       Java
# 4   5    03.10.1978             QA Automation Engineer         QA
#
#            Локация З/п в валюте найма
# 0  Санкт-Петербург       140 000,00 ₽
# 1           Москва       130 000,00 ₽
# 2  Санкт-Петербург       200 000,00 ₽
# 3           Москва       250 000,00 ₽
# 4  Санкт-Петербург       172 413,00 ₽

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58 entries, 0 to 57
# Data columns (total 6 columns):
# id                    58 non-null int64
# Дата рождения         58 non-null object
# Вакансия              58 non-null object
# Технология            58 non-null object
# Локация               58 non-null object
# З/п в валюте найма    58 non-null object
# dtypes: int64(1), object(5)
# memory usage: 2.8+ KB

# %%
df['Дата рождения'] = pd.to_datetime(df['Дата рождения'])

df.iloc[:, 1].dt.year
# Out:
# 0     1994
# 1     1993
# 2     1983
# 3     1989
# 4     1978
# 5     1973
# 6     1991
# 7     1982
# 8     1988
# 9     1990
# 10    1991
# 11    1982
# 12    1988
# 13    1990
# 14    1986
# 15    1982
# 16    1984
# 17    1995
# 18    1972
# 19    1985
# 20    1990
# 21    1991
# 22    1970
# 23    1987
# 24    1989
# 25    1991
# 26    1991
# 27    1990
# 28    1992
# 29    1990
# 30    1992
# 31    1983
# 32    1981
# 33    1994
# 34    1988
# 35    1977
# 36    1988
# 37    1990
# 38    1988
# 39    1992
# 40    1986
# 41    1989
# 42    1989
# 43    1996
# 44    1978
# 45    1985
# 46    1979
# 47    1989
# 48    1992
# 49    1985
# 50    1987
# 51    1987
# 52    1993
# 53    1991
# 54    1985
# 55    1976
# 56    1986
# 57    1989
# Name: Дата рождения, dtype: int64

# %%
df['age'] = 2020 - df.iloc[:, 1].dt.year
df
# Out:
#     id Дата рождения                                    Вакансия   Технология  \
# 0    1    1994-04-18             Инженер-программист 2 категории           JS
# 1    2    1993-03-27           Разработчик информационных систем         .NET
# 2    3    1983-11-24                              Java Developer         Java
# 3    4    1989-09-06                               Архитектор ПО         Java
# 4    5    1978-03-10                      QA Automation Engineer           QA
# 5    6    1973-08-21                          Big Data Developer     Big Data
# 6    7    1991-10-10                                JS Developer           JS
# 7    8    1982-08-16            Разработчик мобильных приложений      Android
# 8    9    1988-05-16             Инженер-программист 2 категории         .NET
# 9   10    1990-01-12                               Java Engineer         Java
# 10  11    1991-04-02                         Инженер-программист   JavaScript
# 11  12    1982-11-02                               .NET Engineer         .NET
# 12  13    1988-04-11                         JavaScript Engineer   JavaScript
# 13  14    1990-09-04                           Software Engineer           JS
# 14  15    1986-03-16         Head of Software Testing Department           QA
# 15  16    1982-08-30                              Java Developer         Java
# 16  17    1984-05-01                          Data / DWH Analyst           DB
# 17  18    1995-08-28                                JS Developer   JavaScript
# 18  19    1972-02-02                    Senior Software Engineer           BI
# 19  20    1985-09-21                                 QA Engineer           QA
# 20  21    1990-06-07                     Разработчик интерфейсов   JavaScript
# 21  22    1991-11-13                                   3D Artist      GameDev
# 22  23    1970-03-02                               Senior Tester           QA
# 23  24    1987-10-29                         Инженер-программист   JavaScript
# 24  25    1989-05-03                          Big Data Developer        Scala
# 25  26    1991-12-29           Разработчик информационных систем         .NET
# 26  27    1991-01-11                        Фронтенд разработчик   JavaScript
# 27  28    1990-09-10                              Java Developer         Java
# 28  29    1992-04-17           Разработчик информационных систем         .NET
# 29  30    1990-12-11                          Big Data Developer     Big Data
# 30  31    1992-09-02                       Senior Java developer         Java
# 31  32    1983-12-19                               Game Designer      GameDev
# 32  33    1981-09-26                              Java Developer         Java
# 33  34    1994-03-04                               iOS Developer          iOS
# 34  35    1988-12-23                               iOS Developer          iOS
# 35  36    1977-08-28                                      BI Dev           BI
# 36  37    1988-04-05                                     PHP Dev          PHP
# 37  38    1990-03-04                         JavaScript Engineer   JavaScript
# 38  39    1988-10-06                    Senior Software Engineer         Java
# 39  40    1992-02-17                    Test Automation Engineer           QA
# 40  41    1986-05-27  Специалист по продаже консалтинговых услуг        Sales
# 41  42    1989-10-10                           ASP.NET Developer         .NET
# 42  43    1989-07-26                               С++ Developer          C++
# 43  44    1996-04-01                          Software Developer  GameDev\C++
# 44  45    1978-01-25                               С++ Developer          C++
# 45  46    1985-10-25                       Senior Java developer         Java
# 46  47    1979-01-06                          Solution Architect    OpenStack
# 47  48    1989-06-03                                      JS Dev           JS
# 48  49    1992-04-07                                     PHP Dev          PHP
# 49  50    1985-09-02                              Java Developer         Java
# 50  51    1987-04-08                                 ASP.NET Dev         .NET
# 51  52    1987-12-26                       Senior Java Developer         Java
# 52  53    1993-07-02                         Android-разработчик      Android
# 53  54    1991-06-20           Разработчик информационных систем         .NET
# 54  55    1985-04-11                               .NET Engineer         .NET
# 55  56    1976-08-01                               С++ Developer         С++
# 56  57    1986-12-09                                    Java Dev         Java
# 57  58    1989-04-15                                      JS Dev           JS
#
#               Локация З/п в валюте найма  age
# 0     Санкт-Петербург       140 000,00 ₽   26
# 1              Москва       130 000,00 ₽   27
# 2     Санкт-Петербург       200 000,00 ₽   37
# 3              Москва       250 000,00 ₽   31
# 4     Санкт-Петербург       172 413,00 ₽   42
# 5     Санкт-Петербург       280 000,00 ₽   47
# 6              Москва       129 000,00 ₽   29
# 7              Москва       185 000,00 ₽   38
# 8     Санкт-Петербург       160 000,00 ₽   32
# 9      Краков; Польша        9 500,00 zł   30
# 10             Москва       170 000,00 ₽   29
# 11    Гданьск; Польша       12 000,00 zł   38
# 12     Краков; Польша       10 500,00 zł   32
# 13    Вроцлав; Польша        9 500,00 zł   30
# 14    Санкт-Петербург       375 000,00 ₽   34
# 15             Москва       180 000,00 ₽   38
# 16       Прага; Чехия       60 000,00 Kč   36
# 17             Москва       160 000,00 ₽   25
# 18    Санкт-Петербург       200 000,00 ₽   48
# 19    Санкт-Петербург       135 000,00 ₽   35
# 20    Санкт-Петербург       113 000,00 ₽   30
# 21             Минск           $2 000,00   29
# 22    Санкт-Петербург       145 000,00 ₽   50
# 23    Санкт-Петербург       190 000,00 ₽   33
# 24    Санкт-Петербург       250 000,00 ₽   31
# 25             Москва       200 000,00 ₽   29
# 26    Санкт-Петербург       300 000,00 ₽   29
# 27             Москва       170 000,00 ₽   30
# 28             Москва       190 000,00 ₽   28
# 29    Санкт-Петербург       185 000,00 ₽   30
# 30    Санкт-Петербург       264 367,82 ₽   28
# 31             Минск           $1 800,00   37
# 32             Москва       210 000,00 ₽   39
# 33    Санкт-Петербург       184 000,00 ₽   26
# 34    Санкт-Петербург       170 000,00 ₽   32
# 35    Санкт-Петербург       161 000,00 ₽   43
# 36             Москва       201 149,43 ₽   32
# 37     Краков; Польша       13 000,00 zł   30
# 38    София; Болгария        lev6 446,00   32
# 39  Будапешт; Венгрия       Ft650 000,00   28
# 40             Москва       150 000,00 ₽   34
# 41    Санкт-Петербург       165 000,00 ₽   31
# 42             Москва       206 896,00 ₽   31
# 43    Санкт-Петербург       130 631,00 ₽   24
# 44    Нижний Новгород       100 000,00 ₽   42
# 45    Санкт-Петербург       252 900,00 ₽   35
# 46              Минск             6000 $   41
# 47    Санкт-Петербург       200 000,00 ₽   31
# 48             Москва       169 540,23 ₽   28
# 49             Москва       300 000,00 ₽   35
# 50             Москва       180 000,00 ₽   33
# 51    Санкт-Петербург       210 000,00 ₽   33
# 52    Санкт-Петербург       183 908,00 ₽   27
# 53             Москва       150 000,00 ₽   29
# 54       Чехия; Прага       80 000,00 Kč   35
# 55    Атлон; Ирландия         € 3 212,00   44
# 56    Атлон; Ирландия         € 4 000,00   34
# 57    Атлон; Ирландия         € 2 980,00   31
