# %% [markdown]
# ## Введение в  API
#
# Аббревиатура API расшифровывается как Application Programming Interface, или интерфейс для программирования приложений.
#
# Интерфейс, который позволяет разработчикам использовать готовые блоки для построения приложения.
#
# В случае веб-приложений, API может отдавать данные в отличном от стандартного HTML формате, благодаря чему им удобно пользоваться при написании собственных приложений.
#
# Сторонние общедоступные API чаще всего отдают данные в одном из двух форматов: XML или JSON.

# %% [markdown]
# API ВКонтакте — это интерфейс, который позволяет получать информацию из базы данных vk.com с помощью http-запросов к специальному серверу.
#
# Вам не нужно знать в подробностях, как устроена база, из каких таблиц и полей каких типов она состоит — достаточно того, что API-запрос об этом «знает».
#
# Синтаксис запросов и тип возвращаемых ими данных строго определены на стороне самого сервиса.
#
# **Методы**
# https://vk.com/dev.php?method=first_guide
#
# **Версии**
# https://vk.com/dev/versions

# %% [markdown]
# ## Самый простой пример API без аутентификации

# %%
import geocoder
g = geocoder.arcgis('Москва')
obj = [g.json['lat'], g.json['lng']]
obj
# Out:
# [55.75696000000005, 37.61502000000007]

# %%
import requests
r = requests.get('https://api.sunrise-sunset.org/json?lat={}&lng={}'.format(obj[0], obj[1]))
r_dict = r.json()

r_dict['results']
# Out:
# {'sunrise': '1:29:11 AM',
#  'sunset': '5:22:47 PM',
#  'solar_noon': '9:25:59 AM',
#  'day_length': '15:53:36',
#  'civil_twilight_begin': '12:42:19 AM',
#  'civil_twilight_end': '6:09:40 PM',
#  'nautical_twilight_begin': '11:34:13 PM',
#  'nautical_twilight_end': '7:17:45 PM',
#  'astronomical_twilight_begin': '12:00:01 AM',
#  'astronomical_twilight_end': '12:00:01 AM'}

# %% [markdown]
# ### Регистрация приложения и получение токена для API VK
#
# Альтернативные инструкции
#
# https://devman.org/qna/63/kak-poluchit-token-polzovatelja-dlja-vkontakte/
#
# https://www.youtube.com/watch?v=JJHtltJPAt0&t=367s
#
# 1) Нажимаете на кнопку создать приложение
#
# 2) Выбираете standalone приложение, указываете название приложения
#
# ![](https://sun9-60.userapi.com/c857736/v857736671/14acdc/66pnWpKHRmM.jpg)
#
# 3) Переходите в настройки, включаете Open API
#
# 4) В поле *адрес сайта* вводите http://localhost
#
# 5) В поле базовый домен вводите localhost
#
# ![](https://sun9-4.userapi.com/c857736/v857736671/14acee/6qdLYkpdBl4.jpg)
#
# 6) Сохраняете изменения
#
# 7) Копируете id приложения
#
# 8) В ссылку
#
# https://oauth.vk.com/authorize?client_id=1&display=page&scope=stats,offline&response_type=token&v=5.103&state=123456
#
#
#
# вместо 1 вставьте **ваш** client_id
#
# 9) Нажимаете разрешить
#
# 10) Сохраняете токен
#
# ![](https://sun9-29.userapi.com/c857736/v857736671/14acf8/2c-F9g7w0jA.jpg)

# %% [markdown]
# Документация requests
#
# https://requests.readthedocs.io/en/master/

# %% [markdown]
# # Использование библиотеки vk_api
#
# https://vk-api.readthedocs.io/en/latest/

# %%
# !pip install vk_api

# %%
import vk_api
with open('credentials.txt', 'r') as c:
    login, password = c.read().strip().split(',')



vk_session = vk_api.VkApi(login, password)
vk_session.auth()

vk = vk_session.get_api()

print(vk.wall.get())

# %%
tools = vk_api.VkTools(vk_session)

# %%
wall = tools.get_all('wall.get', 100, {'owner_id': 1})
wall

# %%
with open('token.txt', 'r') as f:
    token = f.read().strip()

# %%
import requests

r = requests.get('https://api.vk.com/method/users.get?user_id=1',  
                 params = {'access_token':token, 'fields': 'education,universities', 'v':'5.52'})

response = r.json()
response
# Out:
# {'response': [{'id': 1,
#    'first_name': 'Павел',
#    'last_name': 'Дуров',
#    'university': 1,
#    'university_name': 'СПбГУ',
#    'faculty': 0,
#    'faculty_name': '',
#    'graduation': 2006,
#    'universities': [{'id': 1,
#      'country': 1,
#      'city': 2,
#      'name': 'СПбГУ',
#      'graduation': 2006}]}]}

# %% [markdown]
# ## JSON
#
# JSON - текстовый формат данных, следующий за синтаксисом объекта JavaScript, который был популяризирован Дугласом Крокфордом. Несмотря на то, что он очень похож на буквенный синтаксис объекта JavaScript, его можно использовать независимо от JavaScript, и многие среды программирования имеют возможность читать (анализировать) и генерировать JSON.
#
# При работе с модулем requests в нашем репертуаре имеется метод json(), который преобразует объект response в объект класса dict.
#
# Подробнее: https://python-scripts.com/json

# %% [markdown]
# ### Протокол HTTP
#
# Взаимодействие между клиентом и сервером происходит с помощью протогкола http
#
#
# Протокол передачи гипертекста (Hypertext Transfer Protocol - HTTP) - это прикладной протокол для передачи гипертекстовых документов, таких как HTML.
#
# Он создан для связи между веб-браузерами и веб-серверами, хотя в принципе HTTP может использоваться и для других целей.
#
# Протокол следует классической клиент-серверной модели, когда клиент открывает соединение для создания запроса, а затем ждет ответа.
#
# HTTP - это протокол без сохранения состояния, то есть сервер не сохраняет никаких данных (состояние) между двумя парами "запрос-ответ".

# %% [markdown]
# ### Методы запросов
#
# HTTP методы
#
# Для того, чтобы указать серверу на то, какое действие мы хотим произвести с ресурсом, используется тип HTTP-запроса, который также называется HTTP метод. Существует несколько HTTP методов, которые описывают действия с ресурсами. Наиболее часто используемыми являются GET и POST.
#
# ### GET — получение ресурса
#
# Метод GET запрашивает информацию из указанного источника и не влияет на его содержимое. Запрос доступен для кеширования данных и добавления в закладки. Длина запроса ограничена (макс. длина URL - 2048).
#
# Примечание: Строка запроса (имя/значение) отправляется в URL
#
# ``/login-check.php?argument1=value1&argument2=value2``
#
# ### POST — создание ресурса
#
# Метод POST используется для отправки данных, что может оказывать влияние на содержимое ресурса. В отличие от метода GET запросы POST не могут быть кешированы, они не остаются в истории браузера и их нельзя добавить в закладки. Запросы POST не ограничиваются в объеме.
#
# Примечание: Отправляемые данные содержатся в теле запроса.
#
# https://developer.mozilla.org/ru/docs/Web/HTTP/Methods

# %% [markdown]
# https://vk.com/dev/api_limitation_2019

# %%
def get_by_query(length=10):
    query = input('Введите поисковый запрос: ')
#     req = requests.get('https://api.vk.com/method/groups.search', 
#             params = {'access_token':token, 
#                       'v':'5.73', 'q':str(query), 'count':10, 'sort':0}).json()['response']
    req = vk.groups.search(q='python')
    groups = [req['items'][i]['id'] for i in range(length)]
    return groups


result = get_by_query()
result
# Out:
# Введите поисковый запрос: python
# [42565717,
#  38080744,
#  1879,
#  69108280,
#  3183750,
#  11899736,
#  152061199,
#  178774705,
#  119334888,
#  152111071]

# %%
print(result[:5])
# Out:
# [42565717, 38080744, 91313205, 149218373, 142410745]

# %%
grps = '42565717, 3183750, 38080744, 91313205, 159101500, 149218373, 152111071, 142410745, 69108280, 119334888, 55702386, 8056712, 11899736, 26227, 178774705, 12299085, 64524646, 51370544, 52104930, 1879, 24666528, 55927709, 2484973, 37392018, 24847633, 44437312, 180288349, 174948538, 62324702, 163683177, 18405086, 82481391, 113913953, 96469126, 149694058, 41069912, 176456268, 43690334, 68362584, 26332, 125409792, 27975363, 125626212, 6683074, 41070201, 54001977, 94809790, 1540917, 138576816, 55578525, 125748921, 117030524, 134263192, 69235007, 172171969, 98444608, 142919317, 41943023, 111958866, 141441685, 132490011, 19771505, 42226144, 109938878, 95629528, 166600799, 96806600, 88752455, 79303962, 73834539, 73929027, 99411738, 174586137, 177962775, 102016896, 35155841, 31056096, 73284245, 136323479, 164946472, 181442365, 161982342, 152376762, 28849068, 72486321, 75836319, 177184688, 44402703, 93497035, 33008056, 85529744, 196767, 71439824, 21036475, 168928557, 153615722, 77958696, 45964980, 85876191, 67210159, 414329, 136522163, 168602618, 83088252, 85364050, 158529332, 89085936, 64973098, 19049399, 85879138, 99644954, 181854671, 48670798, 189828845, 178395684, 161474904, 183184920, 103770831, 105205241, 156325271, 163875533, 72358301, 181634513, 139463015, 106798928, 28184653, 120569845, 75776747, 97159757, 185859318, 127091358, 21403140, 161179205, 104403202, 151364191, 179798747, 163242932, 153764049, 123814392, 145981744, 61224212, 66818424, 78137512, 34256705, 96545411, 183439669, 135015138, 163948932, 140886058, 5519824, 85963264, 76184733, 101849308, 169081344, 2512258, 181513077, 154241977, 96572266, 40700410, 165919087, 105548822, 168419860, 141757687, 96761545, 72413171, 42699073, 74383639, 92411699, 135173221, 92716197, 11499223, 72768613, 16790049, 38028675, 162585822, 161334283, 163790384, 154868113, 117210834, 174978164, 153535490, 68237396, 4137091, 150837225, 31926731, 133190725, 62844165, 184871786, 124595182, 31952125, 185716562, 116802538, 11321702, 93042289, 186805553, 108231352, 183686208, 78568978, 171563013, 162386559, 74011926, 181733460, 101323492, 170490491, 162635326, 123993734, 187488772, 127943098, 26183174, 100499013, 155669350, 77012164, 149991628, 115882415, 76605127, 180903781, 181436014, 100504635, 112509616, 132431530, 172717058, 112775373, 89740557, 48753457, 128342226, 154462513, 46720750, 152466989, 64394857, 107029776, 49141997, 173104996, 116615094, 58625014, 134941881, 113138455, 186379318, 129661723, 149701538, 97069350, 52291665, 108338844, 172615203, 91019212, 37549778, 93136533, 56050751, 183738581, 86165430, 155007091, 163284622, 172192793, 166590552, 90932328, 164817773, 59117522, 134675739, 181234867, 180312175, 32295183, 131624023, 17717368, 63390879, 187230253, 46069336, 100274529, 89302556, 60168166, 83851508, 7419053, 154625644, 187546559, 75976428, 101010711, 186964994, 115203481, 49469333, 104616289, 72966361, 187849555, 187858513, 171921873, 45060945, 187795937, 102365318, 128463967, 41642131, 60638896, 138649612, 173695051, 187650622, 175971447, 188198085, 179219245, 73142892, 186607466, 156252191, 169224066, 172290568, 27624101, 132978823, 167386192, 154820510, 68324837, 28894361, 66165921, 142539478, 58196136, 147248832, 122317273, 109648161, 85214308, 186965212, 172247687, 177006957, 102187544, 184147470, 51234314, 154307158, 171646546, 52960751, 189777274, 2256105, 72948640, 171250161, 178136277, 152235724, 169028334, 55174017, 169805952, 103981181, 134202833, 47447946, 61311951, 72942040, 60209805, 179134725, 154869422, 65058086, 123256340, 187751104, 159217471, 64183493, 28975347, 159796509, 176685063, 52613012, 118730728, 154946560, 188089871, 147467102, 4393955, 165457600, 122950113, 94878326, 186562266, 177271744, 76387101, 165011004, 173529440, 139132356, 178967190, 179022189, 156435633, 8753212, 78753194, 32134907, 78742735, 187222444, 83121880, 117088805, 186684823, 73759833, 99811605, 174962381, 183191514, 185529590, 186880505, 152061199, 77314003, 155205067, 98101337, 125911892, 30065011, 174480454, 46647018, 604813, 187449879, 125776577, 172250917, 78917989, 179075935, 67980731, 126260583, 22414947, 171611659, 70570233, 173984163, 188187850, 119512688, 187270367, 176816771, 104152316, 185552245, 128343945, 1610056, 164622557, 147164886, 182662428, 185260146, 173147195, 154307206, 186479453, 154246288, 86332463, 186067299, 145117054, 186548015, 189159879, 103431185, 177701479, 142327783, 128634475, 182748998, 188777185, 123550069, 82976508, 180203386, 189428438, 150692114, 172836629, 188085978, 91171327, 132239452, 166727974, 185778588, 102883184, 92040863, 189641677, 74815019, 147973214, 154798208, 185747961'

# %%
# def string_check(obj):
#     if isinstance(obj, str):
#         return obj
#     elif  isinstance(obj, list):
#         return ', '.join((str(x) for x in obj))
import requests
obj = ', '.join((str(x) for x in result[:5]))

req = requests.get('https://api.vk.com/method/groups.getById', 
        params = {'access_token':token, 
                  'v':'5.73', 'fields': 'members_count,activity', 'group_ids': obj})

req.json()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-bc55a6fa3287> in <module>
#       8
#       9 req = requests.get('https://api.vk.com/method/groups.getById',
# ---> 10         params = {'access_token':token,
#      11                   'v':'5.73', 'fields': 'members_count,activity', 'group_ids': obj})
#      12
#
# NameError: name 'token' is not defined

# %%
obj = ', '.join((str(x) for x in result[:5]))
req = vk.groups.getById(group_ids = obj, fields = 'members_count,activity')
req
# Out:
# [{'id': 42565717,
#   'name': 'Python',
#   'screen_name': 'club42565717',
#   'is_closed': 0,
#   'type': 'group',
#   'is_admin': 0,
#   'is_member': 0,
#   'is_advertiser': 0,
#   'members_count': 41560,
#   'activity': 'Открытая группа',
#   'photo_50': 'https://sun9-59.userapi.com/c845524/v845524906/1a71c2/A2r_4JtmiLQ.jpg?ava=1',
#   'photo_100': 'https://sun9-58.userapi.com/c845524/v845524906/1a71c1/2fBtsS0k8XY.jpg?ava=1',
#   'photo_200': 'https://sun9-50.userapi.com/c845524/v845524906/1a71c0/Kfo-eQIn0DU.jpg?ava=1'},
#  {'id': 38080744,
#   'name': 'Python community',
#   'screen_name': 'python_community',
#   'is_closed': 0,
#   'type': 'group',
#   'is_admin': 0,
#   'is_member': 0,
#   'is_advertiser': 0,
#   'members_count': 22714,
#   'activity': 'Открытая группа',
#   'photo_50': 'https://sun9-13.userapi.com/c639622/v639622351/3ef14/2cqSGd8Ns8w.jpg?ava=1',
#   'photo_100': 'https://sun9-26.userapi.com/c639622/v639622351/3ef13/_ugJQpnH-5s.jpg?ava=1',
#   'photo_200': 'https://sun9-23.userapi.com/c639622/v639622351/3ef11/xMwGR_p91LE.jpg?ava=1'},
#  {'id': 1879,
#   'name': "Monty Python's Flying Club (Монти Пайтон)",
#   'screen_name': 'montypython',
#   'is_closed': 0,
#   'type': 'group',
#   'is_admin': 0,
#   'is_member': 0,
#   'is_advertiser': 0,
#   'members_count': 9718,
#   'activity': 'Открытая группа',
#   'photo_50': 'https://sun9-38.userapi.com/c801/g01879/c_313be9bf.jpg?ava=1',
#   'photo_100': 'https://sun9-38.userapi.com/c801/g01879/b_82d005e0.jpg?ava=1',
#   'photo_200': 'https://sun9-38.userapi.com/c801/g01879/b_82d005e0.jpg?ava=1'},
#  {'id': 69108280,
#   'name': 'Python/Django | Pirsipy',
#   'screen_name': 'pirsipy',
#   'is_closed': 0,
#   'type': 'page',
#   'is_admin': 0,
#   'is_member': 0,
#   'is_advertiser': 0,
#   'members_count': 16321,
#   'activity': 'Программное обеспечение',
#   'photo_50': 'https://sun9-46.userapi.com/c625421/v625421162/2651d/7F1E5whPjWw.jpg?ava=1',
#   'photo_100': 'https://sun9-47.userapi.com/c625421/v625421162/2651c/RL9nCyaunhA.jpg?ava=1',
#   'photo_200': 'https://sun9-18.userapi.com/c625421/v625421162/2651b/w8zROT76F0A.jpg?ava=1'},
#  {'id': 3183750,
#   'name': 'Веб программист - PHP, JS, Python, Java, HTML 5',
#   'screen_name': 'php2all',
#   'is_closed': 0,
#   'type': 'page',
#   'is_admin': 0,
#   'is_member': 0,
#   'is_advertiser': 0,
#   'members_count': 124948,
#   'activity': 'Программирование',
#   'photo_50': 'https://sun9-54.userapi.com/c626421/v626421613/941/HSj4ylRsk8k.jpg?ava=1',
#   'photo_100': 'https://sun9-5.userapi.com/c626421/v626421613/940/yKaZLxGShkY.jpg?ava=1',
#   'photo_200': 'https://sun9-49.userapi.com/c626421/v626421613/93f/2EygT_FJKWg.jpg?ava=1'}]

# %%
def get_info(elem):
    
    groupId = elem['id']
    name = elem['name']
    members_count = elem['members_count']
    activity = elem['activity']
    
    return (groupId, name, members_count, activity)
    
# data = list(zip(*map(get_info, response)))

data = list(zip(*map(get_info, req)))

data
# Out:
# [(42565717, 38080744, 1879, 69108280, 3183750),
#  ('Python',
#   'Python community',
#   "Monty Python's Flying Club (Монти Пайтон)",
#   'Python/Django | Pirsipy',
#   'Веб программист - PHP, JS, Python, Java, HTML 5'),
#  (41560, 22714, 9718, 16321, 124948),
#  ('Открытая группа',
#   'Открытая группа',
#   'Открытая группа',
#   'Программное обеспечение',
#   'Программирование')]

# %%
test = list(map(get_info, req))
test
# Out:
# [(42565717, 'Python', 41560, 'Открытая группа'),
#  (38080744, 'Python community', 22714, 'Открытая группа'),
#  (1879, "Monty Python's Flying Club (Монти Пайтон)", 9718, 'Открытая группа'),
#  (69108280, 'Python/Django | Pirsipy', 16321, 'Программное обеспечение'),
#  (3183750,
#   'Веб программист - PHP, JS, Python, Java, HTML 5',
#   124948,
#   'Программирование')]

# %%
import pandas as pd
tf = pd.DataFrame(test, columns = ["groupId", "name", "members_count", "activity"])
tf
# Out:
#     groupId                                             name  members_count  \
# 0  42565717                                           Python          41560
# 1  38080744                                 Python community          22714
# 2      1879        Monty Python's Flying Club (Монти Пайтон)           9718
# 3  69108280                          Python/Django | Pirsipy          16321
# 4   3183750  Веб программист - PHP, JS, Python, Java, HTML 5         124948
#
#                   activity
# 0          Открытая группа
# 1          Открытая группа
# 2          Открытая группа
# 3  Программное обеспечение
# 4         Программирование

# %% [markdown]
# ## Достанем пользователей группы

# %%
group_members = tools.get_all('groups.getMembers', 100, {'group_id': 13366})
group_members

# %%
len(group_members['items'])
# Out:
# 378016

# %% [markdown]
# ## Давайте найдем пересечение подписчиков для групп

# %%
first_group_id = ''
second_group_id = '' 

resolved = vk.utils.resolveScreenName(screen_name='durov')
# Out:
# {'object_id': 1, 'type': 'user'}

# %%
def get_screen_name(url):
    return url.split('/')[-1]

first_group_id, second_group_id = (vk.utils.resolveScreenName(screen_name=get_screen_name(x))['object_id'] 
                                   for x in ('https://vk.com/open_sourcecode', 'https://vk.com/club42565717'))


print(first_group_id, second_group_id)
# Out:
# 142410745 42565717

# %%
def intersection(first, second):
    first_members = tools.get_all('groups.getMembers', 100, {'group_id': first})['items']
    second_members = tools.get_all('groups.getMembers', 100, {'group_id': second})['items']
    return set(first_members).intersection(set(second_members))

common_members = intersection(first_group_id, second_group_id)
len(common_members)
# Out:
# 6853

# %%
#https://vk.com/dev/groups.getMembers
req = requests.get('https://api.vk.com/method/groups.getMembers', 
        params = {'access_token':token, 
                  'v':'5.73', 'fields': 'sex, bdate, city', 'group_id': 174948538, 'offset':1000})

req.json()
# Out:
# {'response': {'count': 2039,
#   'items': [{'id': 443710552,
#     'first_name': 'Лена',
#     'last_name': 'Квасова',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 443892000,
#     'first_name': 'Иван',
#     'last_name': 'Лазутин',
#     'sex': 2,
#     'bdate': '6.1.1984'},
#    {'id': 444011581,
#     'first_name': 'Ирина',
#     'last_name': 'Петрова',
#     'sex': 1,
#     'bdate': '1.7.1995',
#     'city': {'id': 49, 'title': 'Екатеринбург'}},
#    {'id': 444174659,
#     'first_name': 'Дмитрий',
#     'last_name': 'Александров',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 444193913,
#     'first_name': 'Ксюша',
#     'last_name': 'Ряшко',
#     'sex': 1,
#     'bdate': '7.9.1997',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 444286496,
#     'first_name': 'Анастасия',
#     'last_name': 'Панасюк',
#     'sex': 1,
#     'bdate': '7.6.1995',
#     'city': {'id': 37, 'title': 'Владивосток'}},
#    {'id': 444359333,
#     'first_name': 'Ольга',
#     'last_name': 'Странникова',
#     'sex': 1,
#     'bdate': '1.1.1999',
#     'city': {'id': 85, 'title': 'Махачкала'}},
#    {'id': 444594113,
#     'first_name': 'Алина',
#     'last_name': 'Ерёменко',
#     'sex': 1,
#     'bdate': '15.11.1989',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 444637721,
#     'first_name': 'Егор',
#     'last_name': 'Непипенко',
#     'sex': 2,
#     'bdate': '15.11.2003',
#     'city': {'id': 49, 'title': 'Екатеринбург'}},
#    {'id': 444734853,
#     'first_name': 'Рома',
#     'last_name': 'Вайс',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 444834953,
#     'first_name': 'Вероника',
#     'last_name': 'Васильева',
#     'sex': 1,
#     'bdate': '10.2.1983',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 445075025,
#     'first_name': 'Анна',
#     'last_name': 'Афанасьева',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 445904008,
#     'first_name': 'Loyalty',
#     'last_name': 'Man',
#     'sex': 2,
#     'bdate': '13.7.1995',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 445952807,
#     'first_name': 'Мария',
#     'last_name': 'Казанцева',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 446242950,
#     'first_name': 'Валентин',
#     'last_name': 'Давыдов',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 446283353,
#     'first_name': 'Софья',
#     'last_name': 'Цветкова',
#     'sex': 1,
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 446349942,
#     'first_name': 'Вадим',
#     'last_name': 'Урукбаев',
#     'sex': 2,
#     'bdate': '9.6.1998'},
#    {'id': 446505216,
#     'first_name': 'Ема',
#     'last_name': 'Бутенко',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 446745937,
#     'first_name': 'Станистлав',
#     'last_name': 'Молотов',
#     'sex': 2,
#     'bdate': '3.10',
#     'city': {'id': 99, 'title': 'Новосибирск'}},
#    {'id': 447004084,
#     'first_name': 'Семен',
#     'last_name': 'Петренко',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 447709678,
#     'first_name': 'Оксана',
#     'last_name': 'Давыдова',
#     'sex': 1,
#     'bdate': '15.5',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 447814123,
#     'first_name': 'Егор',
#     'last_name': 'Морозов',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 447824664,
#     'first_name': 'Виктор',
#     'last_name': 'Дробыш',
#     'sex': 2,
#     'bdate': '14.4.1999',
#     'city': {'id': 60, 'title': 'Казань'}},
#    {'id': 448014269, 'first_name': 'Дима', 'last_name': 'Воронцов', 'sex': 2},
#    {'id': 448771734,
#     'first_name': 'Диана',
#     'last_name': 'Рябова',
#     'sex': 1,
#     'bdate': '29.2.1984',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 449681083,
#     'first_name': 'Марсель',
#     'last_name': 'Скрашевский',
#     'sex': 2,
#     'bdate': '2.8',
#     'city': {'id': 106, 'title': 'Оренбург'}},
#    {'id': 449850412,
#     'first_name': 'Алексей',
#     'last_name': 'Сафронов',
#     'sex': 2},
#    {'id': 450370361,
#     'first_name': 'Марина',
#     'last_name': 'Ершова',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 450786865,
#     'first_name': 'Иван',
#     'last_name': 'Сюськалов',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 450794432,
#     'first_name': 'Ксюша',
#     'last_name': 'Мешкова',
#     'sex': 1,
#     'bdate': '7.10',
#     'city': {'id': 104, 'title': 'Омск'}},
#    {'id': 451576852,
#     'first_name': 'Август',
#     'last_name': 'Церковный',
#     'sex': 2,
#     'bdate': '15.11.1994',
#     'city': {'id': 158, 'title': 'Челябинск'}},
#    {'id': 451858573,
#     'first_name': 'Алексей',
#     'last_name': 'Кулаков',
#     'sex': 2,
#     'bdate': '6.6.1984',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 452946270,
#     'first_name': 'Ева',
#     'last_name': 'Петрова',
#     'sex': 1,
#     'bdate': '7.7.2000',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 453043477,
#     'first_name': 'Светлана',
#     'last_name': 'Вецало',
#     'sex': 1,
#     'bdate': '10.8.1989',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 453540035,
#     'first_name': 'Саша',
#     'last_name': 'Ефремов',
#     'sex': 2,
#     'bdate': '11.10.1992',
#     'city': {'id': 20950, 'title': 'Новый Уренгой'}},
#    {'id': 453544941,
#     'first_name': 'Polyakova',
#     'last_name': 'Inna',
#     'sex': 1,
#     'city': {'id': 146, 'title': 'Тула'}},
#    {'id': 453763302,
#     'first_name': 'Владимир',
#     'last_name': 'Абрамов',
#     'sex': 2,
#     'bdate': '5.5.1985'},
#    {'id': 453767479,
#     'first_name': 'Иван',
#     'last_name': 'Володин',
#     'sex': 2,
#     'bdate': '20.6',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 454016427,
#     'first_name': 'Регина',
#     'last_name': 'Олейник',
#     'sex': 1,
#     'bdate': '14.11.1989',
#     'city': {'id': 104, 'title': 'Омск'}},
#    {'id': 454121552,
#     'first_name': 'Карина',
#     'last_name': 'Матвеева',
#     'sex': 1,
#     'bdate': '23.4.1989',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 454252925,
#     'first_name': 'Илья',
#     'last_name': 'Сивков',
#     'sex': 2,
#     'bdate': '11.8.1981',
#     'city': {'id': 25, 'title': 'Барнаул'}},
#    {'id': 454899281,
#     'first_name': 'Ира',
#     'last_name': 'Волкова',
#     'sex': 1,
#     'bdate': '3.6.1982'},
#    {'id': 455177669,
#     'first_name': 'Лена',
#     'last_name': 'Головач',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 455211458,
#     'first_name': 'Света',
#     'last_name': 'Попова',
#     'sex': 1,
#     'bdate': '13.6.1998',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 455546568,
#     'first_name': 'Ева',
#     'last_name': 'Щерба',
#     'sex': 1,
#     'bdate': '15.7.2003',
#     'city': {'id': 17, 'title': 'Абакан'}},
#    {'id': 455593785,
#     'first_name': 'Максим',
#     'last_name': 'Тукан',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 455762028,
#     'first_name': 'Ирина',
#     'last_name': 'Скрябина',
#     'sex': 1,
#     'bdate': '17.8.1999',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 455823853,
#     'first_name': 'Егор',
#     'last_name': 'Калмыков',
#     'sex': 2,
#     'bdate': '7.7.1988',
#     'city': {'id': 49, 'title': 'Екатеринбург'}},
#    {'id': 455849754,
#     'first_name': 'Игорь',
#     'last_name': 'Ляпин',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 455916919,
#     'first_name': 'Танюшка',
#     'last_name': 'Кравченко',
#     'sex': 1,
#     'bdate': '18.11.1996',
#     'city': {'id': 10, 'title': 'Волгоград'}},
#    {'id': 456091486,
#     'first_name': 'Олег',
#     'last_name': 'Крушлов',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 456365013,
#     'first_name': 'Антон',
#     'last_name': 'Белый',
#     'sex': 2,
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 456532266, 'first_name': 'Денис', 'last_name': 'Аризона', 'sex': 2},
#    {'id': 456639833,
#     'first_name': 'Андрей',
#     'last_name': 'Антипов',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 456748240,
#     'first_name': 'Jordan',
#     'last_name': 'Belfort',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 456840860,
#     'first_name': 'Сария',
#     'last_name': 'Ахунова',
#     'sex': 1,
#     'bdate': '3.7.1987'},
#    {'id': 456897473,
#     'first_name': 'Екатерина',
#     'last_name': 'Горбачёва',
#     'sex': 1,
#     'bdate': '10.1.2002'},
#    {'id': 456915100,
#     'first_name': 'Алексей',
#     'last_name': 'Сатановский',
#     'sex': 2,
#     'city': {'id': 1201, 'title': 'Glasgow'}},
#    {'id': 457036790,
#     'first_name': 'Диана',
#     'last_name': 'Рассудина',
#     'sex': 1,
#     'bdate': '22.10.1999',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 457244863,
#     'first_name': 'Ербол',
#     'last_name': 'Нурмаганбетов',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 457540772,
#     'first_name': 'Жанна',
#     'last_name': 'Рудина',
#     'sex': 1,
#     'bdate': '8.4.1995',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 457653222,
#     'first_name': 'Jack',
#     'last_name': 'Sherman',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 457690082,
#     'first_name': 'Александра',
#     'last_name': 'Рыбкина',
#     'sex': 1,
#     'bdate': '6.7.2000',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 458133776,
#     'first_name': 'Егор',
#     'last_name': 'Филиппов',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 458960452,
#     'first_name': 'Никита',
#     'last_name': 'Иванова',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 459001197,
#     'first_name': 'Ульяна',
#     'last_name': 'Леонтьева',
#     'sex': 1,
#     'bdate': '28.8.1992',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 459122897,
#     'first_name': 'Алина',
#     'last_name': 'Гончарова',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 459198329,
#     'first_name': 'Константин',
#     'last_name': 'Лихачёв',
#     'sex': 2,
#     'bdate': '8.9.2003',
#     'city': {'id': 3531, 'title': 'Петровск'}},
#    {'id': 459334236,
#     'first_name': 'Глеб',
#     'last_name': 'Волобуев',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 459400828,
#     'first_name': 'Элина',
#     'last_name': 'Масаева',
#     'sex': 2,
#     'bdate': '6.2.2004'},
#    {'id': 459674199,
#     'first_name': 'Алина',
#     'last_name': 'Крац',
#     'sex': 2,
#     'city': {'id': 1914764, 'title': 'Tokyo'}},
#    {'id': 459773935,
#     'first_name': 'Элеонора',
#     'last_name': 'Финагина',
#     'sex': 1,
#     'bdate': '11.4.1987',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 459881412,
#     'first_name': 'Евдокия',
#     'last_name': 'Полякова',
#     'sex': 1,
#     'bdate': '5.5.1987',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 460532467,
#     'first_name': 'Алиса',
#     'last_name': 'Саприна',
#     'sex': 1,
#     'bdate': '18.4.1996'},
#    {'id': 460790478,
#     'first_name': 'Элеонора',
#     'last_name': 'Финагина',
#     'sex': 1,
#     'bdate': '21.7.1990',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 461375059,
#     'first_name': 'Елена',
#     'last_name': 'Самохина',
#     'sex': 1,
#     'bdate': '1.3.1994'},
#    {'id': 461785205,
#     'first_name': 'Инна',
#     'last_name': 'Шпак',
#     'sex': 1,
#     'bdate': '5.5.1991',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 461992716,
#     'first_name': 'Игорь',
#     'last_name': 'Касторнов',
#     'sex': 1,
#     'bdate': '2.2.1995',
#     'city': {'id': 6823, 'title': 'Łódź'}},
#    {'id': 462068912,
#     'first_name': 'Кларина',
#     'last_name': 'Шелкова',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 462127546, 'first_name': 'Максим', 'last_name': 'Успанов', 'sex': 2},
#    {'id': 462249048,
#     'first_name': 'Маша',
#     'last_name': 'Брезова',
#     'sex': 1,
#     'bdate': '20.8.1993',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 462308241,
#     'first_name': 'Елизавета',
#     'last_name': 'Александрова',
#     'sex': 1,
#     'bdate': '28.7.2002',
#     'city': {'id': 144, 'title': 'Томск'}},
#    {'id': 462724428,
#     'first_name': 'Мария',
#     'last_name': 'Степанова',
#     'sex': 1,
#     'bdate': '25.6.1988',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 462836534,
#     'first_name': 'Алина',
#     'last_name': 'Беляева',
#     'sex': 1,
#     'bdate': '3.7.1981',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 463548066,
#     'first_name': 'Наталья',
#     'last_name': 'Милая',
#     'sex': 1,
#     'bdate': '3.6.1994',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 463599151,
#     'first_name': 'Петя',
#     'last_name': 'Лисицин',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 463630290,
#     'first_name': 'Светлана',
#     'last_name': 'Дмитриева',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 463932436,
#     'first_name': 'Мика',
#     'last_name': 'Джабраилова',
#     'sex': 1,
#     'bdate': '23.12.1996'},
#    {'id': 464065304,
#     'first_name': 'Анна',
#     'last_name': 'Владимирова',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 464077060,
#     'first_name': 'DELETED',
#     'last_name': '',
#     'deactivated': 'deleted',
#     'sex': 2},
#    {'id': 464140360,
#     'first_name': 'Татьяна',
#     'last_name': 'Братухина',
#     'sex': 1,
#     'bdate': '25.1',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 464231818,
#     'first_name': 'Сулейманова',
#     'last_name': 'Гуля',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 464412523,
#     'first_name': 'Руслан',
#     'last_name': 'Майер',
#     'sex': 2,
#     'bdate': '9.8.1995',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 464464754,
#     'first_name': 'Карина',
#     'last_name': 'Волкова',
#     'sex': 1,
#     'bdate': '4.5.1990',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 464630369,
#     'first_name': 'Жанна',
#     'last_name': 'Денисова',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 464774822,
#     'first_name': 'Кондрат',
#     'last_name': 'Шарапов',
#     'sex': 2,
#     'bdate': '13.12.2000',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 464978776,
#     'first_name': 'Злата',
#     'last_name': 'Сафьянова',
#     'sex': 1,
#     'bdate': '20.7.1982',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 465011532,
#     'first_name': 'Анастасия',
#     'last_name': 'Чернышёва',
#     'sex': 1,
#     'bdate': '18.3'},
#    {'id': 465502501,
#     'first_name': 'Лера',
#     'last_name': 'Лебедь',
#     'sex': 1,
#     'bdate': '18.3.1995',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 465637463,
#     'first_name': 'Александра',
#     'last_name': 'Пономарева',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 465763648,
#     'first_name': 'Владислав',
#     'last_name': 'Филатов',
#     'sex': 2,
#     'bdate': '8.5.1998',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 465768738,
#     'first_name': 'Артём',
#     'last_name': 'Верников',
#     'sex': 2,
#     'bdate': '15.10.1990',
#     'city': {'id': 104, 'title': 'Омск'}},
#    {'id': 466257365,
#     'first_name': 'Альбина',
#     'last_name': 'Ладовская',
#     'sex': 1,
#     'bdate': '5.2',
#     'city': {'id': 197, 'title': 'Всеволожск'}},
#    {'id': 466546804,
#     'first_name': 'Алена',
#     'last_name': 'Котова',
#     'sex': 1,
#     'bdate': '15.8.1996',
#     'city': {'id': 151, 'title': 'Уфа'}},
#    {'id': 466701812,
#     'first_name': 'Алена',
#     'last_name': 'Иванова',
#     'sex': 1,
#     'bdate': '1.1'},
#    {'id': 466843412,
#     'first_name': 'Елизавета',
#     'last_name': 'Вернер',
#     'sex': 1,
#     'bdate': '12.6.1914',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 467172986,
#     'first_name': 'Vlada',
#     'last_name': 'Paradise',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 467281840,
#     'first_name': 'Дмитрий',
#     'last_name': 'Носов',
#     'sex': 2,
#     'bdate': '20.7.1992'},
#    {'id': 467298253,
#     'first_name': 'Денис',
#     'last_name': 'Прохоров',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 467301531,
#     'first_name': 'Хаким',
#     'last_name': 'Шамсутдинов',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 467325335,
#     'first_name': 'Flowers',
#     'last_name': 'Russia',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 467337153,
#     'first_name': 'Екатерина',
#     'last_name': 'Петрушкина',
#     'sex': 1,
#     'bdate': '20.6.2004',
#     'city': {'id': 14, 'title': 'Нур-Султан / Астана'}},
#    {'id': 467485728,
#     'first_name': 'Елизавета',
#     'last_name': 'Смирнова',
#     'sex': 1,
#     'bdate': '16.7',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 467601305,
#     'first_name': 'Анна',
#     'last_name': 'Кут',
#     'sex': 1,
#     'bdate': '17.5.1990'},
#    {'id': 468040005,
#     'first_name': 'Иван',
#     'last_name': 'Ингатьев',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 468133009,
#     'first_name': 'Эдвард',
#     'last_name': 'Хачатрян',
#     'sex': 2,
#     'bdate': '21.1.1993',
#     'city': {'id': 98, 'title': 'Новороссийск'}},
#    {'id': 468764813,
#     'first_name': 'Елена',
#     'last_name': 'Охлобыстина',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 468892812,
#     'first_name': 'Вера',
#     'last_name': 'Иванчева',
#     'sex': 1,
#     'bdate': '19.1'},
#    {'id': 469691252,
#     'first_name': 'Лерина',
#     'last_name': 'Кисаренкова',
#     'sex': 1,
#     'bdate': '6.6.1988',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 469773795,
#     'first_name': 'Оля',
#     'last_name': 'Смирнова',
#     'sex': 1,
#     'bdate': '22.1.1990',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 469784567,
#     'first_name': 'Алина',
#     'last_name': 'Газизова',
#     'sex': 1,
#     'bdate': '27.1',
#     'city': {'id': 151, 'title': 'Уфа'}},
#    {'id': 469935048,
#     'first_name': 'Лариса',
#     'last_name': 'Стропилова',
#     'sex': 1,
#     'bdate': '17.5.1987',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 470034050,
#     'first_name': 'Ирина',
#     'last_name': 'Владимировна',
#     'sex': 1,
#     'city': {'id': 26, 'title': 'Белгород'}},
#    {'id': 470625574,
#     'first_name': 'Ksenya',
#     'last_name': 'Safronova',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 470913119,
#     'first_name': 'Виктория',
#     'last_name': 'Иютина',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 470950679,
#     'first_name': 'Александр',
#     'last_name': 'Левченко',
#     'sex': 2,
#     'bdate': '7.7.1984',
#     'city': {'id': 1004461, 'title': 'Нариманов'}},
#    {'id': 471608375,
#     'first_name': 'For',
#     'last_name': 'What',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 471622858,
#     'first_name': 'Анастасия',
#     'last_name': 'Марушова',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 471686962,
#     'first_name': 'Τамара',
#     'last_name': 'Εфремова',
#     'sex': 1,
#     'bdate': '1.4.1990',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 471694892,
#     'first_name': 'Денис',
#     'last_name': 'Агапыч',
#     'sex': 2,
#     'bdate': '11.1.1991',
#     'city': {'id': 123, 'title': 'Самара'}},
#    {'id': 471778576,
#     'first_name': 'DELETED',
#     'last_name': '',
#     'deactivated': 'deleted',
#     'sex': 1},
#    {'id': 471815963,
#     'first_name': 'Илья',
#     'last_name': 'Дементьев',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 472084577,
#     'first_name': 'Елена',
#     'last_name': 'Смирнова',
#     'sex': 1,
#     'bdate': '13.7.1993'},
#    {'id': 472246676,
#     'first_name': 'Амангелди',
#     'last_name': 'Мамбетов',
#     'sex': 2,
#     'bdate': '9.6.1999',
#     'city': {'id': 204, 'title': 'Бишкек'}},
#    {'id': 472630706,
#     'first_name': 'Анастасия',
#     'last_name': 'Болотова',
#     'sex': 1,
#     'bdate': '26.12',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 472630735,
#     'first_name': 'Анастасия',
#     'last_name': 'Павлова',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 472636703,
#     'first_name': 'Эдуард',
#     'last_name': 'Карякин',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 472664588,
#     'first_name': 'Алексей',
#     'last_name': 'Кот',
#     'sex': 2,
#     'bdate': '12.5.1998',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 472729335,
#     'first_name': 'Marina',
#     'last_name': 'Adzhigabulova',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 472922649,
#     'first_name': 'Александра',
#     'last_name': 'Рудова',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 473469396,
#     'first_name': 'Михаил',
#     'last_name': 'Петров',
#     'sex': 2,
#     'bdate': '19.9.1974',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 473884869,
#     'first_name': 'Тимур',
#     'last_name': 'Сафаргалиев',
#     'sex': 1,
#     'bdate': '4.7',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 474013108,
#     'first_name': 'Олег',
#     'last_name': 'Разов',
#     'sex': 2,
#     'bdate': '10.9.1999',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 474097115,
#     'first_name': 'Сергей',
#     'last_name': 'Брежнев',
#     'sex': 2,
#     'bdate': '8.4',
#     'city': {'id': 75, 'title': 'Курск'}},
#    {'id': 474301417,
#     'first_name': 'Светлана',
#     'last_name': 'Александрова',
#     'sex': 1,
#     'bdate': '2.8',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 474678152,
#     'first_name': 'Анна',
#     'last_name': 'Титова',
#     'sex': 1,
#     'bdate': '14.3'},
#    {'id': 474930524,
#     'first_name': 'Яковлева',
#     'last_name': 'Людмила',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 474959484,
#     'first_name': 'Максим',
#     'last_name': 'Иванов',
#     'sex': 2,
#     'bdate': '10.2.1993',
#     'city': {'id': 10, 'title': 'Волгоград'}},
#    {'id': 475047023,
#     'first_name': 'Анна',
#     'last_name': 'Кобзева',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 475551755,
#     'first_name': 'Владимир',
#     'last_name': 'Смерти',
#     'sex': 2,
#     'city': {'id': 5331, 'title': 'Los Angeles'}},
#    {'id': 475762142,
#     'first_name': 'Тёма',
#     'last_name': 'Боголепов',
#     'sex': 2,
#     'bdate': '22.12.1986',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 476008409,
#     'first_name': 'Максим',
#     'last_name': 'Ившин',
#     'sex': 2,
#     'bdate': '26.6.1998',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 476037846,
#     'first_name': 'София',
#     'last_name': 'Кузнецова',
#     'sex': 1,
#     'bdate': '29.11.1991',
#     'city': {'id': 99, 'title': 'Новосибирск'}},
#    {'id': 476212961,
#     'first_name': 'Adria',
#     'last_name': 'Gil',
#     'sex': 2,
#     'bdate': '1.1.1992',
#     'city': {'id': 1901501, 'title': 'Barcelona'}},
#    {'id': 476367718,
#     'first_name': 'Милана',
#     'last_name': 'Рейманг',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 476723732,
#     'first_name': 'Илья',
#     'last_name': 'Ильин',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 476752504,
#     'first_name': 'Урал',
#     'last_name': 'Рахимов',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 476758412,
#     'first_name': 'Дима',
#     'last_name': 'Андреев',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 476860327,
#     'first_name': 'Алла',
#     'last_name': 'Кузнецова',
#     'sex': 1,
#     'bdate': '19.6.1991',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 477082913,
#     'first_name': 'Владимир',
#     'last_name': 'Ержанов',
#     'sex': 2,
#     'bdate': '5.3.1910',
#     'city': {'id': 21166, 'title': 'Кант'}},
#    {'id': 477282851,
#     'first_name': 'Сергей',
#     'last_name': 'Кравченко',
#     'sex': 2,
#     'bdate': '1.1.1989',
#     'city': {'id': 95, 'title': 'Нижний Новгород'}},
#    {'id': 477405097,
#     'first_name': 'Оксана',
#     'last_name': 'Степаненко',
#     'sex': 1,
#     'bdate': '18.12.1988',
#     'city': {'id': 10, 'title': 'Волгоград'}},
#    {'id': 477464502,
#     'first_name': 'Евгения',
#     'last_name': 'Бондарева',
#     'sex': 1,
#     'bdate': '18.7.1991',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 477882667,
#     'first_name': 'Vanshanu',
#     'last_name': 'Raj',
#     'sex': 2,
#     'bdate': '25.10.1992',
#     'city': {'id': 437, 'title': 'Delhi'}},
#    {'id': 478042681,
#     'first_name': 'Петя',
#     'last_name': 'Иваноа',
#     'sex': 2,
#     'bdate': '13.7.1995',
#     'city': {'id': 37, 'title': 'Владивосток'}},
#    {'id': 478093325,
#     'first_name': 'Виктория',
#     'last_name': 'Соловьёва',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 478107367,
#     'first_name': 'Расул',
#     'last_name': 'Мусаев',
#     'sex': 2,
#     'bdate': '26.8.1998',
#     'city': {'id': 18300, 'title': 'Кизляр'}},
#    {'id': 478173463,
#     'first_name': 'Роман',
#     'last_name': 'Малых',
#     'sex': 2,
#     'bdate': '11.8.1979',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 478197929,
#     'first_name': 'Александр',
#     'last_name': 'Соловьёв',
#     'sex': 2,
#     'bdate': '14.7.2000',
#     'city': {'id': 144, 'title': 'Томск'}},
#    {'id': 478330855,
#     'first_name': 'Хома',
#     'last_name': 'Росс',
#     'sex': 2,
#     'bdate': '12.4.1992'},
#    {'id': 478551021,
#     'first_name': 'Rusikjon',
#     'last_name': 'Teshayev',
#     'sex': 2,
#     'bdate': '19.5.1999',
#     'city': {'id': 3522, 'title': 'Бухара'}},
#    {'id': 478667610,
#     'first_name': 'Александра',
#     'last_name': 'Ростовский',
#     'sex': 1,
#     'bdate': '8.9.1990',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 478885288,
#     'first_name': 'Prosto',
#     'last_name': 'Fabr',
#     'sex': 2,
#     'bdate': '6.6.1966'},
#    {'id': 479354589,
#     'first_name': 'Данил',
#     'last_name': 'Романов',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 479443055,
#     'first_name': 'Мстислав',
#     'last_name': 'Шихранов',
#     'sex': 2,
#     'bdate': '12.3.1979',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 479554270,
#     'first_name': 'Кристина',
#     'last_name': 'Фомичева',
#     'sex': 1,
#     'bdate': '12.3.1996',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 479617370,
#     'first_name': 'Имануил',
#     'last_name': 'Рубен',
#     'sex': 2,
#     'bdate': '4.4.1982',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 479803577,
#     'first_name': 'Иван',
#     'last_name': 'Иванов',
#     'sex': 2,
#     'bdate': '12.3.1995'},
#    {'id': 480022121,
#     'first_name': 'Роман',
#     'last_name': 'Новиков',
#     'sex': 2,
#     'bdate': '15.12.1997',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 480059707,
#     'first_name': 'Артем',
#     'last_name': 'Черный',
#     'sex': 2,
#     'bdate': '1.3.1991',
#     'city': {'id': 49, 'title': 'Екатеринбург'}},
#    {'id': 480092403,
#     'first_name': 'Саша',
#     'last_name': 'Мотов',
#     'sex': 2,
#     'bdate': '15.4.2000',
#     'city': {'id': 2642, 'title': 'Черкассы'}},
#    {'id': 480540611,
#     'first_name': 'Юлия',
#     'last_name': 'Посохова',
#     'sex': 1,
#     'bdate': '5.4.1994',
#     'city': {'id': 119, 'title': 'Ростов-на-Дону'}},
#    {'id': 480550562,
#     'first_name': 'Никита',
#     'last_name': 'Светлов',
#     'sex': 2,
#     'bdate': '15.7.1991',
#     'city': {'id': 136, 'title': 'Сургут'}},
#    {'id': 480594807,
#     'first_name': 'Виктория',
#     'last_name': 'Панова',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 480653326,
#     'first_name': 'Сергей',
#     'last_name': 'Ларин',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 480962951,
#     'first_name': 'Виктория',
#     'last_name': 'Некрасова',
#     'sex': 1,
#     'bdate': '7.5.1999',
#     'city': {'id': 37, 'title': 'Владивосток'}},
#    {'id': 480978500,
#     'first_name': 'Ирина',
#     'last_name': 'Никитина',
#     'sex': 1,
#     'bdate': '21.6.1991',
#     'city': {'id': 10, 'title': 'Волгоград'}},
#    {'id': 481255992,
#     'first_name': 'Эмилия',
#     'last_name': 'Миллер',
#     'sex': 1,
#     'bdate': '8.7.1992'},
#    {'id': 481430515,
#     'first_name': 'Andrey',
#     'last_name': 'Dobryi',
#     'sex': 2,
#     'city': {'id': 110, 'title': 'Пермь'}},
#    {'id': 481628667,
#     'first_name': 'Lyudmila',
#     'last_name': 'Yurova',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 481701262,
#     'first_name': 'Дана',
#     'last_name': 'Нергеш',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 482028530,
#     'first_name': 'Дима',
#     'last_name': 'Лемешкин',
#     'sex': 2,
#     'bdate': '14.1.2004',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 482076541,
#     'first_name': 'Omar',
#     'last_name': 'Bastardo',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 482262038,
#     'first_name': 'Максим',
#     'last_name': 'Ярошенко',
#     'sex': 2,
#     'bdate': '1.1.1991',
#     'city': {'id': 49, 'title': 'Екатеринбург'}},
#    {'id': 482266278,
#     'first_name': 'Дима',
#     'last_name': 'Фролов',
#     'sex': 2,
#     'bdate': '4.8.1990'},
#    {'id': 482294521,
#     'first_name': 'Екатерина',
#     'last_name': 'Рожкова',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 482325465,
#     'first_name': 'Ясен',
#     'last_name': 'Хрен',
#     'sex': 2,
#     'bdate': '1.5.1991',
#     'city': {'id': 37, 'title': 'Владивосток'}},
#    {'id': 482698103,
#     'first_name': 'Оля',
#     'last_name': 'Андреева',
#     'sex': 1,
#     'bdate': '28.7.1979',
#     'city': {'id': 10, 'title': 'Волгоград'}},
#    {'id': 482931245,
#     'first_name': 'Александр',
#     'last_name': 'Лазарев',
#     'sex': 2,
#     'bdate': '30.5.1995',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 483016536,
#     'first_name': 'Валентина',
#     'last_name': 'Ольшанская',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 483196792,
#     'first_name': 'Владислав',
#     'last_name': 'Сергеевич',
#     'sex': 2,
#     'bdate': '28.8.1988',
#     'city': {'id': 95, 'title': 'Нижний Новгород'}},
#    {'id': 483406409,
#     'first_name': 'Марк',
#     'last_name': 'Артюхов',
#     'sex': 2,
#     'bdate': '18.9.1988',
#     'city': {'id': 10, 'title': 'Волгоград'}},
#    {'id': 483516402,
#     'first_name': 'Кирилл',
#     'last_name': 'Шолохов',
#     'sex': 2,
#     'bdate': '1.1.1994',
#     'city': {'id': 99, 'title': 'Новосибирск'}},
#    {'id': 483563003,
#     'first_name': 'Светочка',
#     'last_name': 'Кулинарова',
#     'sex': 1,
#     'bdate': '1.6.1996'},
#    {'id': 483615597,
#     'first_name': 'Anton',
#     'last_name': 'Mateev',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 483722702,
#     'first_name': 'Катя',
#     'last_name': 'Бараш',
#     'sex': 1,
#     'bdate': '19.3.1994',
#     'city': {'id': 60, 'title': 'Казань'}},
#    {'id': 483816600,
#     'first_name': 'Валерия',
#     'last_name': 'Козлова',
#     'sex': 1,
#     'city': {'id': 110, 'title': 'Пермь'}},
#    {'id': 483852528,
#     'first_name': 'Данил',
#     'last_name': 'Овчаров',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 483890869,
#     'first_name': 'Настя',
#     'last_name': 'Сурженко',
#     'sex': 1,
#     'bdate': '3.12.1996',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 483947158,
#     'first_name': 'Сашка',
#     'last_name': 'Журавлёв',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 483988227,
#     'first_name': 'Evil',
#     'last_name': 'Bitch',
#     'sex': 1,
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 484363729,
#     'first_name': 'Женя',
#     'last_name': 'Павлов',
#     'sex': 2,
#     'bdate': '29.3.1993',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 484464501,
#     'first_name': 'Лейсан',
#     'last_name': 'Ибрагимова',
#     'sex': 1,
#     'bdate': '10.1.1985',
#     'city': {'id': 60, 'title': 'Казань'}},
#    {'id': 484595512,
#     'first_name': 'Кирилл',
#     'last_name': 'Кирилов',
#     'sex': 2,
#     'bdate': '8.12.1975',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 484944498,
#     'first_name': 'Родион',
#     'last_name': 'Орлов',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 485001532,
#     'first_name': 'Елена',
#     'last_name': 'Машкова',
#     'sex': 1,
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 485009696,
#     'first_name': 'Оксана',
#     'last_name': 'Коновалова',
#     'sex': 1,
#     'bdate': '27.6.1983',
#     'city': {'id': 143, 'title': 'Тольятти'}},
#    {'id': 485072268,
#     'first_name': 'Стас',
#     'last_name': 'Гуров',
#     'sex': 2,
#     'bdate': '21.10.2001',
#     'city': {'id': 57, 'title': 'Иркутск'}},
#    {'id': 485245403,
#     'first_name': 'Александра',
#     'last_name': 'Амосова',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 485313347,
#     'first_name': 'Иван',
#     'last_name': 'Ожегов',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 485337663,
#     'first_name': 'Саша',
#     'last_name': 'Полуторов',
#     'sex': 2,
#     'bdate': '31.3.2004',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 485720526,
#     'first_name': 'Любовь',
#     'last_name': 'Сирашева',
#     'sex': 1,
#     'bdate': '7.5.1995',
#     'city': {'id': 42, 'title': 'Воронеж'}},
#    {'id': 485785526,
#     'first_name': 'Мария',
#     'last_name': 'Комарова',
#     'sex': 1,
#     'bdate': '11.1.1995',
#     'city': {'id': 61, 'title': 'Калининград'}},
#    {'id': 485910534,
#     'first_name': 'Ксения',
#     'last_name': 'Зайцева',
#     'sex': 1,
#     'bdate': '4.9.1992',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 486057220,
#     'first_name': 'Мария',
#     'last_name': 'Сенцова',
#     'sex': 1,
#     'bdate': '19.7.1992',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 486099314,
#     'first_name': 'Ангелина',
#     'last_name': 'Макарова',
#     'sex': 1,
#     'bdate': '6.12.1985',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 486306229,
#     'first_name': 'Марина',
#     'last_name': 'Рудковская',
#     'sex': 1,
#     'bdate': '21.5.1989',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 486310630,
#     'first_name': 'Владимир',
#     'last_name': 'Пукин',
#     'sex': 2,
#     'bdate': '27.10.1986',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 486336728,
#     'first_name': 'Yuliya',
#     'last_name': 'Olyanich',
#     'sex': 1,
#     'bdate': '17.5.1990',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 486349890,
#     'first_name': 'Антон',
#     'last_name': 'Антипов',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 486357999,
#     'first_name': 'Настя',
#     'last_name': 'Мирная',
#     'sex': 1,
#     'bdate': '1.1.1994',
#     'city': {'id': 60, 'title': 'Казань'}},
#    {'id': 486365077,
#     'first_name': 'Тимур',
#     'last_name': 'Зубко',
#     'deactivated': 'deleted',
#     'sex': 2},
#    {'id': 486391096,
#     'first_name': 'Tagir',
#     'last_name': 'Aitov',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 486392887,
#     'first_name': 'Ян',
#     'last_name': 'Гиблерт',
#     'sex': 2,
#     'bdate': '1.5.1985',
#     'city': {'id': 73, 'title': 'Красноярск'}},
#    {'id': 486398266,
#     'first_name': 'Артем',
#     'last_name': 'Булатов',
#     'sex': 2,
#     'city': {'id': 110, 'title': 'Пермь'}},
#    {'id': 486665787,
#     'first_name': 'Александр',
#     'last_name': 'Александрович',
#     'sex': 2},
#    {'id': 487090358,
#     'first_name': 'Алиса',
#     'last_name': 'Лебединская',
#     'sex': 1,
#     'bdate': '24.8.2000'},
#    {'id': 487183053,
#     'first_name': 'Дарья',
#     'last_name': 'Будникова',
#     'sex': 1,
#     'bdate': '1.2.1995',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 487434792,
#     'first_name': 'Ренат',
#     'last_name': 'Минов',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 487484874,
#     'first_name': 'Елена',
#     'last_name': 'Тихая',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 487611346,
#     'first_name': 'Еагеша',
#     'last_name': 'Садовская',
#     'sex': 1,
#     'bdate': '8.7.1992',
#     'city': {'id': 99, 'title': 'Новосибирск'}},
#    {'id': 487678252,
#     'first_name': 'Ярослава',
#     'last_name': 'Шульца',
#     'sex': 1,
#     'bdate': '28.1.1993',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 487702941,
#     'first_name': 'Яна',
#     'last_name': 'Байко',
#     'sex': 1,
#     'bdate': '17.10.1988',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 487785649,
#     'first_name': 'Артём',
#     'last_name': 'Смолин',
#     'sex': 2,
#     'bdate': '13.10.1997',
#     'city': {'id': 151, 'title': 'Уфа'}},
#    {'id': 487792576,
#     'first_name': 'Сергей',
#     'last_name': 'Иванов',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 488001245,
#     'first_name': 'Oleg',
#     'last_name': 'Prival',
#     'sex': 2,
#     'bdate': '13.5.1961',
#     'city': {'id': 15839, 'title': 'Долгоруково'}},
#    {'id': 488351355,
#     'first_name': 'Дмитрий',
#     'last_name': 'Элберн',
#     'sex': 2,
#     'bdate': '23.8',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 488499174,
#     'first_name': 'Марина',
#     'last_name': 'Антонова',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 489004029,
#     'first_name': 'Иван',
#     'last_name': 'Семёнов',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 489417454,
#     'first_name': 'Евгения',
#     'last_name': 'Савинкова',
#     'sex': 1,
#     'bdate': '18.5.1996',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 489425740,
#     'first_name': 'Коля',
#     'last_name': 'Вилатовский',
#     'sex': 2,
#     'bdate': '1.3.1985',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 490330520,
#     'first_name': 'Александр',
#     'last_name': 'Наумов',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 490414097,
#     'first_name': 'Андрей',
#     'last_name': 'Александрович',
#     'sex': 2,
#     'bdate': '16.9',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 490464470,
#     'first_name': 'Елизавета',
#     'last_name': 'Колесникова',
#     'sex': 2,
#     'bdate': '20.8'},
#    {'id': 491020481,
#     'first_name': 'Виталя',
#     'last_name': 'Ивашенко',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 491064286,
#     'first_name': 'Артём',
#     'last_name': 'Ершов',
#     'sex': 2,
#     'bdate': '5.1.1988',
#     'city': {'id': 627, 'title': 'Симферополь'}},
#    {'id': 491158243,
#     'first_name': 'Андрей',
#     'last_name': 'Прудников',
#     'sex': 2,
#     'bdate': '6.5.1991',
#     'city': {'id': 1957236, 'title': 'Баку'}},
#    {'id': 491255491, 'first_name': 'Anna', 'last_name': 'Veber', 'sex': 1},
#    {'id': 491424509,
#     'first_name': 'Миша',
#     'last_name': 'Воробьев',
#     'sex': 2,
#     'bdate': '14.2.2000'},
#    {'id': 491509769,
#     'first_name': 'Виталий',
#     'last_name': 'Макарцов',
#     'sex': 2},
#    {'id': 491516186,
#     'first_name': 'Макс',
#     'last_name': 'Алегро',
#     'sex': 2,
#     'bdate': '7.5.1995',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 491560773,
#     'first_name': 'Карина',
#     'last_name': 'Анкиратова',
#     'sex': 1,
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 491828404,
#     'first_name': 'Владимир',
#     'last_name': 'Гладилин',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 491878237,
#     'first_name': 'Максим',
#     'last_name': 'Максимов',
#     'sex': 2,
#     'bdate': '2.2.2000',
#     'city': {'id': 223, 'title': 'Донецк'}},
#    {'id': 492323132,
#     'first_name': 'Светлана',
#     'last_name': 'Сиялова',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 492327691,
#     'first_name': 'Елена',
#     'last_name': 'Зимина',
#     'sex': 1,
#     'bdate': '6.7.1989',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 492663195,
#     'first_name': 'Danil',
#     'last_name': 'Gry',
#     'sex': 2,
#     'bdate': '7.8.1977'},
#    {'id': 493057355,
#     'first_name': 'Даниэль',
#     'last_name': 'Назаров',
#     'sex': 2,
#     'bdate': '5.11.1993',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 493320342,
#     'first_name': 'Денис',
#     'last_name': 'Васильев',
#     'sex': 2,
#     'bdate': '6.1.1989',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 493659260, 'first_name': 'Мария', 'last_name': 'Сергеева', 'sex': 1},
#    {'id': 494022667,
#     'first_name': 'Степан',
#     'last_name': 'Капуста',
#     'sex': 2,
#     'bdate': '6.6.1988',
#     'city': {'id': 122, 'title': 'Рязань'}},
#    {'id': 494053602,
#     'first_name': 'Ангелина',
#     'last_name': 'Филиппова',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 494058451,
#     'first_name': 'Роман',
#     'last_name': 'Иванов',
#     'sex': 2,
#     'bdate': '17.4.2003'},
#    {'id': 494075268,
#     'first_name': 'Карина',
#     'last_name': 'Суворкина',
#     'sex': 1,
#     'bdate': '10.7.2000',
#     'city': {'id': 762, 'title': 'Ереван'}},
#    {'id': 494434119,
#     'first_name': 'Vladimir',
#     'last_name': 'Vasquez',
#     'sex': 2,
#     'bdate': '27.6.1993',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 495092503,
#     'first_name': 'Dona',
#     'last_name': 'Li',
#     'sex': 1,
#     'city': {'id': 17259, 'title': 'Кара-Балта'}},
#    {'id': 495136012,
#     'first_name': 'Ксения',
#     'last_name': 'Назарова',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 495142165, 'first_name': 'Ева', 'last_name': 'Бремкинст', 'sex': 1},
#    {'id': 495245215,
#     'first_name': 'Радий',
#     'last_name': 'Зейнетдинов',
#     'sex': 2,
#     'bdate': '29.11.1999'},
#    {'id': 495251606,
#     'first_name': 'Бодя',
#     'last_name': 'Шолохов',
#     'sex': 2,
#     'bdate': '9.4.1991',
#     'city': {'id': 134, 'title': 'Ставрополь'}},
#    {'id': 495261774,
#     'first_name': 'Владимир',
#     'last_name': 'Епифания',
#     'sex': 2,
#     'bdate': '1.9.1971',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 495301057,
#     'first_name': 'Дима',
#     'last_name': 'Ларин',
#     'sex': 2,
#     'bdate': '31.12.1983',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 495315028,
#     'first_name': 'Елена',
#     'last_name': 'Абалымова',
#     'sex': 1,
#     'bdate': '24.2.1994',
#     'city': {'id': 151, 'title': 'Уфа'}},
#    {'id': 495361013,
#     'first_name': 'Хамитян',
#     'last_name': 'Гареев',
#     'sex': 2,
#     'bdate': '15.1.1964',
#     'city': {'id': 93, 'title': 'Нижневартовск'}},
#    {'id': 495596952,
#     'first_name': 'Вавилен',
#     'last_name': 'Татарский',
#     'sex': 2,
#     'bdate': '7.6.1994'},
#    {'id': 495804451,
#     'first_name': 'Алена',
#     'last_name': 'Казанцева',
#     'sex': 1,
#     'bdate': '25.3.1996',
#     'city': {'id': 61, 'title': 'Калининград'}},
#    {'id': 495945312,
#     'first_name': 'Борис',
#     'last_name': 'Шабанов',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 496133286,
#     'first_name': 'Елена',
#     'last_name': 'Данилова',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 496146093,
#     'first_name': 'Иван',
#     'last_name': 'Фоминов',
#     'sex': 2,
#     'bdate': '29.8.1998'},
#    {'id': 496206868,
#     'first_name': 'Мария',
#     'last_name': 'Звягинцева',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 496521216,
#     'first_name': 'Максим',
#     'last_name': 'Мудрецов',
#     'sex': 2,
#     'bdate': '14.6.1996',
#     'city': {'id': 4529, 'title': 'Рассказово'}},
#    {'id': 496586350,
#     'first_name': 'Валерия',
#     'last_name': 'Симонова',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 496595502,
#     'first_name': 'Юлия',
#     'last_name': 'Романов',
#     'sex': 1,
#     'bdate': '24.7.1983',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 496638043,
#     'first_name': 'Виктория',
#     'last_name': 'Сергеевич',
#     'sex': 1,
#     'bdate': '2.4.1998',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 497057904,
#     'first_name': 'Alexandruc',
#     'last_name': 'Daniel',
#     'sex': 2,
#     'bdate': '25.11.1991'},
#    {'id': 497181256,
#     'first_name': 'Ян',
#     'last_name': 'Петров',
#     'sex': 2,
#     'bdate': '18.4.1950',
#     'city': {'id': 49, 'title': 'Екатеринбург'}},
#    {'id': 497310712,
#     'first_name': 'Ангелина',
#     'last_name': 'Колесникова',
#     'sex': 1,
#     'bdate': '16.7.1989',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 497338127,
#     'first_name': 'Анастасия',
#     'last_name': 'Александрова',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 497518316,
#     'first_name': 'Михаил',
#     'last_name': 'Смирнов',
#     'sex': 2,
#     'bdate': '24.9',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 497520919,
#     'first_name': 'Дарья',
#     'last_name': 'Семёнова',
#     'sex': 1,
#     'bdate': '22.4.1998',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 497537233,
#     'first_name': 'Василий',
#     'last_name': 'Кошкин',
#     'sex': 2,
#     'bdate': '17.11',
#     'city': {'id': 1135212, 'title': 'Минск (деревня)'}},
#    {'id': 497579645,
#     'first_name': 'Юлия',
#     'last_name': 'Степанова',
#     'sex': 1,
#     'bdate': '14.11.1990',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 497633575,
#     'first_name': 'Мария',
#     'last_name': 'Продвигаева',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 497794515,
#     'first_name': 'Киря',
#     'last_name': 'Лисовский',
#     'sex': 2,
#     'bdate': '1.2.1997',
#     'city': {'id': 9930, 'title': 'Балаково'}},
#    {'id': 497908540,
#     'first_name': 'Павел',
#     'last_name': 'Мечников',
#     'sex': 2,
#     'bdate': '9.1.1993',
#     'city': {'id': 42, 'title': 'Воронеж'}},
#    {'id': 498011955,
#     'first_name': 'Диана',
#     'last_name': 'Солнце',
#     'sex': 1,
#     'bdate': '25.11.1991',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 498019493,
#     'first_name': 'Эмилия',
#     'last_name': 'Рей',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 498155883,
#     'first_name': 'Иван',
#     'last_name': 'Иванов',
#     'sex': 1,
#     'bdate': '1.1.1902'},
#    {'id': 498418854,
#     'first_name': 'Александра',
#     'last_name': 'Степанова',
#     'sex': 1,
#     'bdate': '23.12.1991',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 498600649,
#     'first_name': 'Мария',
#     'last_name': 'Соколова',
#     'sex': 1,
#     'bdate': '23.5.1999',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 498682154,
#     'first_name': 'Яна',
#     'last_name': 'Кириллова',
#     'sex': 1,
#     'bdate': '25.8.1992',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 498731751,
#     'first_name': 'Вероника',
#     'last_name': 'Сидорова',
#     'sex': 1,
#     'bdate': '10.2.2000',
#     'city': {'id': 66, 'title': 'Киров'}},
#    {'id': 498746377,
#     'first_name': 'Анна',
#     'last_name': 'Архипова',
#     'sex': 1,
#     'bdate': '28.8.1998',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 498819835,
#     'first_name': 'Светлана',
#     'last_name': 'Кожемякина',
#     'sex': 1,
#     'bdate': '10.9',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 498820359,
#     'first_name': 'Дарья',
#     'last_name': 'Антонова',
#     'sex': 1,
#     'bdate': '12.11.1995',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 498866460,
#     'first_name': 'Светлана',
#     'last_name': 'Орлова',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 498897750,
#     'first_name': 'Ксения',
#     'last_name': 'Орлова',
#     'sex': 1,
#     'bdate': '6.12.1998'},
#    {'id': 498956845,
#     'first_name': 'Изольда',
#     'last_name': 'Бустова',
#     'sex': 1,
#     'bdate': '7.4'},
#    {'id': 499095051,
#     'first_name': 'Jhonlino',
#     'last_name': 'Vasquez',
#     'sex': 2,
#     'bdate': '27.7.1999',
#     'city': {'id': 4794175, 'title': 'La Lara'}},
#    {'id': 499169483,
#     'first_name': 'Ростислав',
#     'last_name': 'Югов',
#     'sex': 2,
#     'bdate': '10.11.1953',
#     'city': {'id': 25, 'title': 'Барнаул'}},
#    {'id': 499356356,
#     'first_name': 'Елена',
#     'last_name': 'Дрожжинова',
#     'sex': 1,
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 499372374,
#     'first_name': 'Ольга',
#     'last_name': 'Евчук',
#     'sex': 1,
#     'bdate': '30.11.1989',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 499413582,
#     'first_name': 'Анастасия',
#     'last_name': 'Бешота',
#     'sex': 1,
#     'bdate': '18.10.1995',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 499525324, 'first_name': 'Shako', 'last_name': 'Rose', 'sex': 2},
#    {'id': 499656687,
#     'first_name': 'Давид',
#     'last_name': 'Решка',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 499705927,
#     'first_name': 'Антонина',
#     'last_name': 'Изотова',
#     'sex': 1,
#     'bdate': '3.2.1997',
#     'city': {'id': 6193, 'title': 'Риддер'}},
#    {'id': 499785332,
#     'first_name': 'Юлия',
#     'last_name': 'Жукова',
#     'sex': 1,
#     'bdate': '29.1.1994',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 499942500,
#     'first_name': 'Дмитрий',
#     'last_name': 'Файзулин',
#     'sex': 2},
#    {'id': 500158259,
#     'first_name': 'Igor',
#     'last_name': 'Presnyackov',
#     'sex': 2},
#    {'id': 500352823,
#     'first_name': 'Таня',
#     'last_name': 'Титова',
#     'sex': 1,
#     'bdate': '21.4.1980',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 500354256,
#     'first_name': 'Лариса',
#     'last_name': 'Миронова',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 500356851,
#     'first_name': 'Элина',
#     'last_name': 'Ильина',
#     'sex': 1,
#     'bdate': '7.12.1986',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 500368340,
#     'first_name': 'Настик',
#     'last_name': 'Алексеева',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 500396976,
#     'first_name': 'Дарья',
#     'last_name': 'Зайцева',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 500425706,
#     'first_name': 'Элина',
#     'last_name': 'Соколова',
#     'sex': 1,
#     'bdate': '16.7.1994',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 500425716,
#     'first_name': 'Элина',
#     'last_name': 'Семенова',
#     'sex': 1,
# ...
#    {'id': 567942346,
#     'first_name': 'Карина',
#     'last_name': 'Кирина',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 567966219,
#     'first_name': 'Zulejka',
#     'last_name': 'Lischneva',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 568021999,
#     'first_name': 'Marina',
#     'last_name': 'Aguilar',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 568058135,
#     'first_name': 'Александр',
#     'last_name': 'Фуник',
#     'sex': 2,
#     'bdate': '7.1.2000',
#     'city': {'id': 95, 'title': 'Нижний Новгород'}},
#    {'id': 568096936,
#     'first_name': 'Александр',
#     'last_name': 'Александр',
#     'sex': 2,
#     'bdate': '13.5.2000'},
#    {'id': 568145676,
#     'first_name': 'Дима',
#     'last_name': 'Реселлер',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 568178614,
#     'first_name': 'Тимоха',
#     'last_name': 'Минин',
#     'sex': 2,
#     'bdate': '5.6.1999',
#     'city': {'id': 49, 'title': 'Екатеринбург'}},
#    {'id': 568202786,
#     'first_name': 'Jaimie',
#     'last_name': 'Taylor',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 568246211,
#     'first_name': 'Гаспарян',
#     'last_name': 'Каро',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 568283846,
#     'first_name': 'Inés',
#     'last_name': 'Campos',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 568301442,
#     'first_name': 'Karla',
#     'last_name': 'Orozco',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 568331439,
#     'first_name': 'Ирина',
#     'last_name': 'Минаева',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 568342412,
#     'first_name': 'Mina',
#     'last_name': 'Sakamoto',
#     'sex': 1,
#     'bdate': '7.10.1995',
#     'city': {'id': 4735370, 'title': 'Bergantín'}},
#    {'id': 568350655,
#     'first_name': 'Dmitry',
#     'last_name': 'Debotov',
#     'sex': 2,
#     'bdate': '7.12.1990'},
#    {'id': 568429120,
#     'first_name': 'Erédira',
#     'last_name': 'Maeda',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 568433729,
#     'first_name': 'Ценители',
#     'last_name': 'Рязань',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 568445096,
#     'first_name': 'Двадцать',
#     'last_name': 'Три',
#     'sex': 1,
#     'bdate': '1.7.2000'},
#    {'id': 568451329,
#     'first_name': 'Alex',
#     'last_name': 'Bozhok',
#     'sex': 2,
#     'bdate': '25.7.1979',
#     'city': {'id': 49, 'title': 'Екатеринбург'}},
#    {'id': 568464853,
#     'first_name': 'Ana',
#     'last_name': 'Ranjada',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 568508206,
#     'first_name': 'Ильяс',
#     'last_name': 'Быстровской',
#     'deactivated': 'deleted',
#     'sex': 2},
#    {'id': 568631930,
#     'first_name': 'Maria',
#     'last_name': 'Suarez',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 568732854,
#     'first_name': 'Егор',
#     'last_name': 'Сербаков',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 568805212,
#     'first_name': 'Мирас',
#     'last_name': 'Айдусов',
#     'sex': 2,
#     'bdate': '1.1.1993'},
#    {'id': 568878748,
#     'first_name': 'Катя',
#     'last_name': 'Вершкова',
#     'sex': 1,
#     'bdate': '20.5.2005'},
#    {'id': 568892212,
#     'first_name': 'Юлианна',
#     'last_name': 'Филиппова',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 568899102,
#     'first_name': 'Дмитрий',
#     'last_name': 'Железодорожный',
#     'sex': 2,
#     'bdate': '5.5.1979',
#     'city': {'id': 37, 'title': 'Владивосток'}},
#    {'id': 569112402,
#     'first_name': 'Alik',
#     'last_name': 'Banov',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 569262421,
#     'first_name': 'Амелия',
#     'last_name': 'Бахирева',
#     'sex': 1,
#     'bdate': '10.5.1975',
#     'city': {'id': 1096, 'title': 'Нижнеудинск'}},
#    {'id': 569272894,
#     'first_name': 'Жандос',
#     'last_name': 'Муханбетпанин',
#     'sex': 2},
#    {'id': 570052743,
#     'first_name': 'Клара',
#     'last_name': 'Минот',
#     'sex': 1,
#     'bdate': '9.7.1997'},
#    {'id': 570069430,
#     'first_name': 'Сергей',
#     'last_name': 'Емельяненко',
#     'sex': 2,
#     'bdate': '8.1.1976',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 570120337,
#     'first_name': 'Владимир',
#     'last_name': 'Решетов',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 570554311,
#     'first_name': 'Сергей',
#     'last_name': 'Рожков',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 571578459,
#     'first_name': 'Анжелика',
#     'last_name': 'Рашкова',
#     'sex': 1,
#     'bdate': '29.10.1999',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 571743496,
#     'first_name': 'Елена',
#     'last_name': 'Соловьёва',
#     'sex': 1,
#     'bdate': '15.5.1989'},
#    {'id': 571798848,
#     'first_name': 'Ирина',
#     'last_name': 'Санжара',
#     'sex': 1,
#     'bdate': '26.4.1969'},
#    {'id': 571814294,
#     'first_name': 'Толик',
#     'last_name': 'Прокофьев',
#     'sex': 2,
#     'bdate': '4.3.1995',
#     'city': {'id': 42, 'title': 'Воронеж'}},
#    {'id': 571854391,
#     'first_name': 'Ксения',
#     'last_name': 'Ковалева',
#     'sex': 1,
#     'bdate': '3.2.1998',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 571994446,
#     'first_name': 'Alena',
#     'last_name': 'Fokina',
#     'sex': 1,
#     'bdate': '10.11.2001',
#     'city': {'id': 282, 'title': 'Минск'}},
#    {'id': 572106532,
#     'first_name': 'Илья',
#     'last_name': 'Островский',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 572291423,
#     'first_name': 'Марина',
#     'last_name': 'Гришина',
#     'sex': 1,
#     'bdate': '1.2.1984',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 572345068,
#     'first_name': 'Joaquín',
#     'last_name': 'Echevarria Medina',
#     'sex': 0},
#    {'id': 572550330,
#     'first_name': 'Наталия',
#     'last_name': 'Корнякова',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 572770950,
#     'first_name': 'Алексей',
#     'last_name': 'Громов',
#     'sex': 2,
#     'bdate': '2.6.1980',
#     'city': {'id': 66, 'title': 'Киров'}},
#    {'id': 572860409,
#     'first_name': 'Эд',
#     'last_name': 'Грязный',
#     'sex': 2,
#     'bdate': '19.3.1990',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 572996634,
#     'first_name': 'Jezyka',
#     'last_name': 'Dubrovina-Spring',
#     'sex': 1,
#     'bdate': '10.5.1988'},
#    {'id': 573161687,
#     'first_name': 'Armando',
#     'last_name': 'Moreno',
#     'sex': 2,
#     'bdate': '28.10',
#     'city': {'id': 1956352, 'title': 'Caracas'}},
#    {'id': 573205153,
#     'first_name': 'Andres',
#     'last_name': 'Gomez',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 573207427,
#     'first_name': 'Workstap',
#     'last_name': 'Dreif',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 573323695,
#     'first_name': 'Изи',
#     'last_name': 'Бест',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 573343803,
#     'first_name': 'Эльмира',
#     'last_name': 'Громова',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 573427346,
#     'first_name': 'Георгий',
#     'last_name': 'Мартынов',
#     'sex': 2,
#     'bdate': '6.5.1992'},
#    {'id': 573461767,
#     'first_name': 'Alejandro',
#     'last_name': 'Almeida',
#     'sex': 2,
#     'bdate': '22.5.1997',
#     'city': {'id': 1954634, 'title': 'Maracay'}},
#    {'id': 573497538,
#     'first_name': 'Зоя',
#     'last_name': 'Завиткова',
#     'sex': 1,
#     'bdate': '1.1.2000',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 573779986,
#     'first_name': 'Амир',
#     'last_name': 'Жумагулов',
#     'sex': 2,
#     'bdate': '15.4.1990',
#     'city': {'id': 14, 'title': 'Нур-Султан / Астана'}},
#    {'id': 573902272,
#     'first_name': 'Вагиф',
#     'last_name': 'Аскеров',
#     'sex': 2,
#     'bdate': '24.8.2000'},
#    {'id': 573944971,
#     'first_name': 'Вадим',
#     'last_name': 'Вадим',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 574083114,
#     'first_name': 'Камиль',
#     'last_name': 'Хусаинов',
#     'sex': 2,
#     'bdate': '31.10.2004'},
#    {'id': 574160693,
#     'first_name': 'Max',
#     'last_name': 'Meyer',
#     'sex': 2,
#     'bdate': '3.1.1996'},
#    {'id': 574304271,
#     'first_name': 'Saidbek',
#     'last_name': 'Bekmurotov',
#     'sex': 2,
#     'bdate': '17.8.2000'},
#    {'id': 574370068,
#     'first_name': 'Никита',
#     'last_name': 'Королёв',
#     'sex': 2,
#     'bdate': '24.4.2003',
#     'city': {'id': 119, 'title': 'Ростов-на-Дону'}},
#    {'id': 574433687,
#     'first_name': 'Fer',
#     'last_name': 'Scag',
#     'sex': 2,
#     'bdate': '2.12.1992',
#     'city': {'id': 1956352, 'title': 'Caracas'}},
#    {'id': 574524346,
#     'first_name': 'Jose',
#     'last_name': 'Lopez',
#     'sex': 2,
#     'bdate': '9.6.1998',
#     'city': {'id': 1956352, 'title': 'Caracas'}},
#    {'id': 574559543,
#     'first_name': 'Edniev',
#     'last_name': 'Ali',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 574628718,
#     'first_name': 'Светлана',
#     'last_name': 'Зорькина',
#     'sex': 1,
#     'bdate': '4.5.1985',
#     'city': {'id': 123, 'title': 'Самара'}},
#    {'id': 574680978,
#     'first_name': 'Иришка',
#     'last_name': 'Пятницкая',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 574962323,
#     'first_name': 'Антон',
#     'last_name': 'Савиных',
#     'sex': 2,
#     'bdate': '28.12',
#     'city': {'id': 1233, 'title': 'Орша'}},
#    {'id': 575095981,
#     'first_name': 'Подуш',
#     'last_name': 'Едтвщту',
#     'sex': 2,
#     'bdate': '5.5.2001',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 575379951,
#     'first_name': '石磊',
#     'last_name': '黄建宏',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 575612986,
#     'first_name': '钟健',
#     'last_name': '邵雅婷',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 575821814,
#     'first_name': 'Pedro',
#     'last_name': 'Macho',
#     'sex': 2,
#     'bdate': '23.1.1966',
#     'city': {'id': 4735503, 'title': 'Barcelona'}},
#    {'id': 575924515,
#     'first_name': 'Анастасия',
#     'last_name': 'Жмых',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 575958364,
#     'first_name': 'Дарья',
#     'last_name': 'Молчанова',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 575990212,
#     'first_name': 'Владимир',
#     'last_name': 'Северинов',
#     'sex': 2,
#     'bdate': '1.1.1982',
#     'city': {'id': 314, 'title': 'Киев'}},
#    {'id': 576026965,
#     'first_name': 'Любовь',
#     'last_name': 'Варвина',
#     'sex': 1,
#     'bdate': '5.6.1986',
#     'city': {'id': 123, 'title': 'Самара'}},
#    {'id': 576079489,
#     'first_name': 'Коля',
#     'last_name': 'Дроздов',
#     'sex': 2,
#     'bdate': '15.4.1985',
#     'city': {'id': 125, 'title': 'Саратов'}},
#    {'id': 576319540,
#     'first_name': 'Xay',
#     'last_name': 'Avazboy',
#     'sex': 1,
#     'bdate': '3.2.1982',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 576419487,
#     'first_name': 'Star',
#     'last_name': 'Xit',
#     'sex': 2,
#     'bdate': '5.2.1989',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 576723591,
#     'first_name': 'Abdullla',
#     'last_name': 'Abdullla',
#     'sex': 2,
#     'bdate': '4.3.1983',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 576786272,
#     'first_name': 'Яблок',
#     'last_name': 'Вкусный',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 576968709,
#     'first_name': 'Денис',
#     'last_name': 'Ка',
#     'sex': 2,
#     'bdate': '3.1.1992',
#     'city': {'id': 104, 'title': 'Омск'}},
#    {'id': 577037029,
#     'first_name': 'Алена',
#     'last_name': 'Хмельницкая',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 577143022,
#     'first_name': 'Brff',
#     'last_name': 'Brff',
#     'sex': 1,
#     'bdate': '13.2.2000',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 577459664,
#     'first_name': 'Aa',
#     'last_name': 'Aa',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 577513500,
#     'first_name': 'Kirill',
#     'last_name': 'Opera',
#     'sex': 2,
#     'bdate': '4.11.1994',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 577647068,
#     'first_name': 'Елена',
#     'last_name': 'Кипупик',
#     'sex': 1,
#     'bdate': '10.4.1988',
#     'city': {'id': 60, 'title': 'Казань'}},
#    {'id': 577708393,
#     'first_name': 'Алена',
#     'last_name': 'Сказкина',
#     'sex': 1,
#     'bdate': '6.8',
#     'city': {'id': 60, 'title': 'Казань'}},
#    {'id': 577736619,
#     'first_name': 'Я-Большой',
#     'last_name': 'Пидр',
#     'sex': 2,
#     'bdate': '9.1.1980'},
#    {'id': 577833215,
#     'first_name': 'Raul',
#     'last_name': 'Perez',
#     'sex': 2,
#     'bdate': '29.3.1977',
#     'city': {'id': 2722547, 'title': 'Valencia'}},
#    {'id': 577944689,
#     'first_name': 'Светлана',
#     'last_name': 'Михальская',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 578023082,
#     'first_name': 'Алексей',
#     'last_name': 'Владимирович',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 578330911,
#     'first_name': 'Светлана',
#     'last_name': 'Панфилова',
#     'sex': 1,
#     'bdate': '5.8.1990'},
#    {'id': 578430528,
#     'first_name': 'Алексей',
#     'last_name': 'Александрович',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 578545717,
#     'first_name': 'Dusaniya',
#     'last_name': 'Sobieski',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 578547107,
#     'first_name': 'Charlyse',
#     'last_name': 'Auyrzhan-Kyzy',
#     'sex': 1,
#     'bdate': '6.3.1974'},
#    {'id': 578631147,
#     'first_name': 'Михаил',
#     'last_name': 'Борозин',
#     'sex': 2,
#     'bdate': '6.5.1990',
#     'city': {'id': 2, 'title': 'Санкт-Петербург'}},
#    {'id': 578789180,
#     'first_name': 'Анастасия',
#     'last_name': 'Луценко',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 578882319,
#     'first_name': 'Светлана',
#     'last_name': 'Ветрова',
#     'sex': 1,
#     'bdate': '1.1.2000',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 579193026,
#     'first_name': 'Аня',
#     'last_name': 'Вишневская',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 579361948,
#     'first_name': 'Qwerty',
#     'last_name': 'Qwerty',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 579416236,
#     'first_name': 'Afina',
#     'last_name': 'Donova',
#     'sex': 1,
#     'bdate': '4.3.1997',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 579501818,
#     'first_name': 'Антон',
#     'last_name': 'Антонов',
#     'sex': 2,
#     'bdate': '1.1.1902',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 579510849,
#     'first_name': 'Дмитрий',
#     'last_name': 'Дмитрий',
#     'deactivated': 'banned',
#     'sex': 2},
#    {'id': 579571558,
#     'first_name': 'Виктория',
#     'last_name': 'Вольф',
#     'sex': 1,
#     'bdate': '16.4.1995',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 579585247,
#     'first_name': 'Семя',
#     'last_name': 'Браун',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 579759391,
#     'first_name': 'Вечно',
#     'last_name': 'Депрессивный',
#     'sex': 2,
#     'bdate': '23.1.2006'},
#    {'id': 579841680,
#     'first_name': 'Денис',
#     'last_name': 'Сивер',
#     'sex': 2,
#     'bdate': '3.5.1996',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 579924678,
#     'first_name': 'Светлана',
#     'last_name': 'Белогурова',
#     'sex': 1,
#     'bdate': '15.10.1991',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 580007750,
#     'first_name': 'Miss',
#     'last_name': 'Merser',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 580013181,
#     'first_name': 'Кристина',
#     'last_name': 'Суменкова',
#     'sex': 1,
#     'bdate': '10.3.2000',
#     'city': {'id': 1, 'title': 'Москва'}},
#    {'id': 580056177,
#     'first_name': 'Оля',
#     'last_name': 'Голова',
#     'sex': 1,
#     'bdate': '8.11.1995'},
#    {'id': 580067464,
#     'first_name': 'Павел',
#     'last_name': 'Соколов',
#     'sex': 2,
#     'bdate': '8.4.1993'},
#    {'id': 580073837,
#     'first_name': 'Сергей',
#     'last_name': 'Петров',
#     'sex': 2,
#     'bdate': '3.1.1971'},
#    {'id': 580166236,
#     'first_name': 'Tonya',
#     'last_name': 'Zarkovina',
#     'deactivated': 'banned',
#     'sex': 1},
#    {'id': 580239389,
#     'first_name': 'Sarti',
#     'last_name': 'Veronica',
#     'sex': 1,
#     'bdate': '17.7.1999'},
#    {'id': 580377900,
#     'first_name': 'Дашка',
#     'last_name': 'Коновалова',
#     'sex': 1,
#     'bdate': '22.10.1987',
#     'city': {'id': 467, 'title': 'Могилёв'}},
#    {'id': 580586796,
#     'first_name': 'Семён',
#     'last_name': 'Сабуров',
#     'sex': 2,
#     'bdate': '13.5.1967'}]}}

# %%
len(req.json()['response']['items'])
# Out:
# 1000

# %%
df = pd.DataFrame.from_records(items)
df['city'] = list(map(get_title, items))
df
# Out:
#              id first_name   last_name  sex      bdate             city  \
# 0        130712  Александр    Казанцев    2        6.8           Москва
# 1        206026    Алексей  Колесников    2  12.3.1986  Санкт-Петербург
# 2        418131     Серёжа    Горбачёв    2       3.12           Москва
# 3        455447     Сергей    Ситников    2   6.4.1980           Москва
# 4        523329       Иван     Либеров    2        1.4           Москва
# ...         ...        ...         ...  ...        ...              ...
# 2034  581845358   Светлана    Романова    1        NaN             None
# 2035  581926201  Александр      Киреев    2  20.2.1998  Санкт-Петербург
# 2036  582027147  Александр    Васильев    2        NaN          Иркутск
# 2037  582256370       Luis       Perez    2   7.4.1994             None
# 2038  582474645      Слава    Алексеев    2  20.8.1988           Москва
#
#      deactivated
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# ...          ...
# 2034      banned
# 2035         NaN
# 2036         NaN
# 2037         NaN
# 2038         NaN
#
# [2039 rows x 7 columns]

# %% [markdown]
# ## Немного про параметры

# %%
import pandas as pd
import requests
from collections import defaultdict
from math import ceil



class Parser:
    """Для работы модуля необходимо импортировать библиотеку requests и math"""
    
    
    def __init__(self, regionCode, link = ''):
        self.dict = defaultdict(list)
        self.regionCode = regionCode
        if link:
            requests.get(link).json()
            
        r = requests.get(f'http://openngopublicapi.h5.crftr.net/v1/org/?page=1&regionCode={regionCode}').json()
        try:
            self.iters = ceil(int(r['total'])/int(r['count']))
            print('По запросу получено {} страниц'.format(self.iters))
        except Exception as e:
            print(e)

    
    def getData(self, pageNum = '', **kwargs):
        """Получение данных в виде словаря.
        pageNum - отвечает за количество страниц, которые будут распарсены
        также можно передать словарь"""
        if not pageNum:
            pageNum = self.iters
        else:
            pageNum = pageNum
        for page in range(1, pageNum):
            try:
                if not kwargs:
                    r = requests.get('http://openngopublicapi.h5.crftr.net/v1/org/?page={}&regionCode={}'
                                     .format(page, self.regionCode)).json()
                else:
                    r = requests.get('http://openngopublicapi.h5.crftr.net/v1/org/?page={}&regionCode={}'
                                     .format(page, self.regionCode),  params = kwargs).json()                
                items = r['items']
                for item in items:
                    for key in item:
                        self.dict[key].append(item[key]) #клянусь, запись  k,v почему то не работала
            except Exception as e:
                print('page {} not fetched because of :'.format(page), e)
                pass
            
        return self.dict
        
    
d = Parser(64)
dct = d.getData(3)
dct

# %% [markdown]
# Библиотеки для работы с API  Vk
#
# https://vk-api.readthedocs.io/en/latest/
#
# https://github.com/python273/vk_api
#
# https://pypi.org/project/vk-api/
#
# https://habr.com/ru/post/319178/
